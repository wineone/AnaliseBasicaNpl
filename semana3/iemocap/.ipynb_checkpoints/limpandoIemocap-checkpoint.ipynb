# %% [markdown]
# ### Analise de sentimentos pela base de dados do iemocap

# %% [markdown]
# # 1 - Bibliotecas

# %%
# vectorizer 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression #classification model
from sklearn.metrics import confusion_matrix, classification_report, f1_score # performance evaluation criteria
from sklearn.metrics import accuracy_score
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
import matplotlib
import matplotlib.patches as mpatches

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2 - Visualização dos dados

# %%
data = pd.read_csv("data")

data.head(50)
# Out:
#              Session_ID           Time_Record  \
# 0   Ses01F_impro01_F000  [006.2901-008.2357]:
# 1   Ses01F_impro01_M000  [007.5712-010.4750]:
# 2   Ses01F_impro01_F001  [010.0100-011.3925]:
# 3   Ses01F_impro01_M001  [010.9266-014.6649]:
# 4   Ses01F_impro01_F002  [014.8872-018.0175]:
# 5   Ses01F_impro01_M002  [016.8352-019.7175]:
# 6   Ses01F_impro01_F003  [019.2900-020.7875]:
# 7   Ses01F_impro01_F004  [021.3257-024.7400]:
# 8   Ses01F_impro01_M003  [023.4700-028.0300]:
# 9   Ses01F_impro01_F005  [027.4600-031.4900]:
# 10  Ses01F_impro01_M004  [028.3950-031.2117]:
# 11  Ses01F_impro01_M005  [031.2660-039.3875]:
# 12  Ses01F_impro01_F006  [038.9650-043.5900]:
# 13  Ses01F_impro01_M006  [041.2300-046.9800]:
# 14  Ses01F_impro01_F007  [046.5800-052.1900]:
# 15  Ses01F_impro01_M007  [051.4000-057.6400]:
# 16  Ses01F_impro01_F008  [056.1600-058.8225]:
# 17  Ses01F_impro01_M008  [058.1800-062.5900]:
# 18  Ses01F_impro01_F009  [061.8700-065.9700]:
# 19  Ses01F_impro01_M009  [065.5100-073.0000]:
# 20  Ses01F_impro01_F010  [066.4200-069.3400]:
# 21  Ses01F_impro01_F011  [072.4500-082.2600]:
# 22  Ses01F_impro01_M010  [081.5900-086.0300]:
# 23  Ses01F_impro01_F012  [085.2700-088.0200]:
# 24  Ses01F_impro01_M011  [087.1500-094.3900]:
# 25  Ses01F_impro01_F013  [093.6700-097.0218]:
# 26  Ses01F_impro01_M012  [095.8600-098.6800]:
# 27  Ses01F_impro01_F014  [097.8900-102.9600]:
# 28  Ses01F_impro01_M013  [101.8400-107.8700]:
# 29  Ses01F_impro01_F015  [103.9700-106.7100]:
# 30  Ses01F_impro02_F000  [007.2688-016.6000]:
# 31                   M:                 Yeah.
# 32  Ses01F_impro02_M000  [017.6000-020.6264]:
# 33  Ses01F_impro02_F001  [019.8500-022.7800]:
# 34  Ses01F_impro02_M001  [021.7600-027.5558]:
# 35  Ses01F_impro02_F002  [026.5659-032.2895]:
# 36  Ses01F_impro02_F003  [032.3075-037.9600]:
# 37  Ses01F_impro02_M002  [038.8500-045.0900]:
# 38  Ses01F_impro02_F004  [047.3400-053.1100]:
# 39  Ses01F_impro02_M003  [052.7100-059.0534]:
# 40  Ses01F_impro02_F005  [058.7500-061.3100]:
# 41  Ses01F_impro02_M004  [061.7500-065.0550]:
# 42  Ses01F_impro02_F006  [064.2550-068.4700]:
# 43  Ses01F_impro02_M005  [069.3400-074.2900]:
# 44  Ses01F_impro02_F007  [072.3900-078.5700]:
# 45  Ses01F_impro02_M006  [080.0300-086.9900]:
# 46  Ses01F_impro02_F008  [087.2031-091.0900]:
# 47  Ses01F_impro02_F009  [091.5500-095.8800]:
# 48  Ses01F_impro02_F010  [097.9400-102.1900]:
# 49  Ses01F_impro02_M007  [103.2700-107.1000]:
#
#                                         Transcription
# 0                                          Excuse me.
# 1                             Do you have your forms?
# 2                                               Yeah.
# 3                                    Let me see them.
# 4                                 Is there a problem?
# 5                   Who told you to get in this line?
# 6                                            You did.
# 7   You were standing at the beginning and you dir...
# 8   Okay. But I didn't tell you to get in this lin...
# 9         Well what's the problem?  Let me change it.
# 10                           This form is a Z.X.four.
# 11  You can't--  This is not the line for Z.X.four...
# 12  What?  I'm getting an ID.  This is why I'm her...
# 13  No. I need another set of ID to prove this is ...
# 14  How am I supposed to get an ID without an ID? ...
# 15  I don't know.  But I need an ID to pass this f...
# 16                             I'm here to get an ID.
# 17            No.  I need another ID, a separate one.
# 18              Like what?  Like a birth certificate?
# 19  A birth certificate, a passport...a student ID...
# 20              Who the hell has a birth certificate?
# 21  Yes but my wallet was stolen, I don't have any...
# 22  Yeah.  We keep it on file, but we need an ID t...
# 23                             That's out of control.
# 24  I don't understand why this is so complicated ...
# 25               How long have you been working here?
# 26                                 Actually too long.
# 27  Clearly.  You know, do you have like a supervi...
# 28  Yeah.  Do you want to see my supervisor?  Huh?...
# 29       That would - I would appreciate that.  Yeah.
# 30        Did you get the mail? So you saw my letter?
# 31                                                NaN
# 32                                     It's not fair.
# 33                                     Yeah.  I know.
# 34  I don't understand.  You've already done so mu...
# 35  I don't know.  I put in that. request too. The...
# 36  I guess, you know, everybody has to make sacri...
# 37  I don't know, it's just not fair.  I think you...
# 38  There's people that have given more though, yo...
# 39  I just don't see how they can make you leave w...
# 40                                            I know.
# 41                      Then why is that fair?  Why--
# 42  There's babies over there, though, that need m...
# 43  I don't know how you can be okay with this?  I...
# 44  I'm not okay with it, but I don't-- it's not l...
# 45  I'm just trying to think of another way.  I'm ...
# 46                    Just, you know, kicking myself.
# 47        like you sign up because you need money and
# 48                 things just aren't what they seem.
# 49                              This is a stupid war.

# %%
data.shape
# Out:
# (10239, 3)

# %%
target = pd.read_csv("target")

target.head(50)
# Out:
#              Session_ID Sentiment  Valence  Activation  Dominance
# 0   Ses01F_impro01_F000       neu      2.5         2.5        2.5
# 1   Ses01F_impro01_F001       neu      2.5         2.5        2.5
# 2   Ses01F_impro01_F002       neu      2.5         2.5        2.5
# 3   Ses01F_impro01_F003       xxx      2.5         3.0        3.0
# 4   Ses01F_impro01_F004       xxx      2.5         3.0        2.5
# 5   Ses01F_impro01_F005       neu      2.5         3.5        2.0
# 6   Ses01F_impro01_F006       fru      2.0         3.5        3.5
# 7   Ses01F_impro01_F007       fru      2.5         3.5        3.5
# 8   Ses01F_impro01_F008       fru      2.0         3.5        3.5
# 9   Ses01F_impro01_F009       fru      2.0         3.5        3.0
# 10  Ses01F_impro01_F010       xxx      1.5         3.5        3.5
# 11  Ses01F_impro01_F011       fru      2.0         3.5        3.5
# 12  Ses01F_impro01_F012       ang      2.0         3.5        3.5
# 13  Ses01F_impro01_F013       fru      2.0         4.0        3.5
# 14  Ses01F_impro01_F014       neu      2.5         3.5        3.5
# 15  Ses01F_impro01_F015       fru      2.0         3.5        3.0
# 16  Ses01F_impro01_M000       fru      2.5         2.0        2.5
# 17  Ses01F_impro01_M001       fru      2.5         2.0        2.5
# 18  Ses01F_impro01_M002       fru      2.0         3.5        3.5
# 19  Ses01F_impro01_M003       fru      2.5         3.5        3.5
# 20  Ses01F_impro01_M004       fru      2.0         4.0        3.5
# 21  Ses01F_impro01_M005       fru      2.0         3.5        3.5
# 22  Ses01F_impro01_M006       fru      2.0         3.5        3.5
# 23  Ses01F_impro01_M007       fru      2.5         3.5        3.0
# 24  Ses01F_impro01_M008       fru      2.0         3.5        3.5
# 25  Ses01F_impro01_M009       fru      2.5         3.5        4.0
# 26  Ses01F_impro01_M010       fru      2.0         4.5        4.0
# 27  Ses01F_impro01_M011       ang      2.0         4.0        4.0
# 28  Ses01F_impro01_M012       xxx      3.0         1.5        2.0
# 29  Ses01F_impro01_M013       ang      2.0         4.5        4.5
# 30  Ses01F_impro02_F000       sad      2.5         2.0        1.5
# 31  Ses01F_impro02_F001       sad      2.0         1.5        1.5
# 32  Ses01F_impro02_F002       sad      2.0         1.5        1.5
# 33  Ses01F_impro02_F003       neu      2.0         2.0        2.0
# 34  Ses01F_impro02_F004       sad      2.5         2.0        2.5
# 35  Ses01F_impro02_F005       sad      2.0         2.0        2.5
# 36  Ses01F_impro02_F006       neu      2.5         2.5        2.5
# 37  Ses01F_impro02_F007       xxx      2.0         3.5        3.0
# 38  Ses01F_impro02_F008       sad      1.5         2.0        1.5
# 39  Ses01F_impro02_F009       xxx      1.5         1.5        2.0
# 40  Ses01F_impro02_F010       sad      2.0         1.5        2.0
# 41  Ses01F_impro02_F011       xxx      2.5         2.5        2.5
# 42  Ses01F_impro02_F012       sad      3.5         2.0        1.5
# 43  Ses01F_impro02_F013       sad      1.5         2.0        2.0
# 44  Ses01F_impro02_F014       sad      1.5         2.0        2.0
# 45  Ses01F_impro02_F015       sad      2.0         2.5        2.5
# 46  Ses01F_impro02_F016       neu      2.0         1.0        2.5
# 47  Ses01F_impro02_F017       sad      3.5         3.0        2.5
# 48  Ses01F_impro02_F018       neu      2.5         2.5        2.5
# 49  Ses01F_impro02_F019       sad      2.5         1.5        2.0

# %% [markdown]
# ### Note que estamos fazendo o merge pelo id, e descartamos as linhas que não tem sentimento mapeado.

# %% [markdown]
# ### Fazemos o merge e removemos linhas que não tem id associado.

# %%
merged = pd.merge(data,target,on = "Session_ID")

merged.head(50)
# Out:
#              Session_ID           Time_Record  \
# 0   Ses01F_impro01_F000  [006.2901-008.2357]:
# 1   Ses01F_impro01_M000  [007.5712-010.4750]:
# 2   Ses01F_impro01_F001  [010.0100-011.3925]:
# 3   Ses01F_impro01_M001  [010.9266-014.6649]:
# 4   Ses01F_impro01_F002  [014.8872-018.0175]:
# 5   Ses01F_impro01_M002  [016.8352-019.7175]:
# 6   Ses01F_impro01_F003  [019.2900-020.7875]:
# 7   Ses01F_impro01_F004  [021.3257-024.7400]:
# 8   Ses01F_impro01_M003  [023.4700-028.0300]:
# 9   Ses01F_impro01_F005  [027.4600-031.4900]:
# 10  Ses01F_impro01_M004  [028.3950-031.2117]:
# 11  Ses01F_impro01_M005  [031.2660-039.3875]:
# 12  Ses01F_impro01_F006  [038.9650-043.5900]:
# 13  Ses01F_impro01_M006  [041.2300-046.9800]:
# 14  Ses01F_impro01_F007  [046.5800-052.1900]:
# 15  Ses01F_impro01_M007  [051.4000-057.6400]:
# 16  Ses01F_impro01_F008  [056.1600-058.8225]:
# 17  Ses01F_impro01_M008  [058.1800-062.5900]:
# 18  Ses01F_impro01_F009  [061.8700-065.9700]:
# 19  Ses01F_impro01_M009  [065.5100-073.0000]:
# 20  Ses01F_impro01_F010  [066.4200-069.3400]:
# 21  Ses01F_impro01_F011  [072.4500-082.2600]:
# 22  Ses01F_impro01_M010  [081.5900-086.0300]:
# 23  Ses01F_impro01_F012  [085.2700-088.0200]:
# 24  Ses01F_impro01_M011  [087.1500-094.3900]:
# 25  Ses01F_impro01_F013  [093.6700-097.0218]:
# 26  Ses01F_impro01_M012  [095.8600-098.6800]:
# 27  Ses01F_impro01_F014  [097.8900-102.9600]:
# 28  Ses01F_impro01_M013  [101.8400-107.8700]:
# 29  Ses01F_impro01_F015  [103.9700-106.7100]:
# 30  Ses01F_impro02_F000  [007.2688-016.6000]:
# 31  Ses01F_impro02_M000  [017.6000-020.6264]:
# 32  Ses01F_impro02_F001  [019.8500-022.7800]:
# 33  Ses01F_impro02_M001  [021.7600-027.5558]:
# 34  Ses01F_impro02_F002  [026.5659-032.2895]:
# 35  Ses01F_impro02_F003  [032.3075-037.9600]:
# 36  Ses01F_impro02_M002  [038.8500-045.0900]:
# 37  Ses01F_impro02_F004  [047.3400-053.1100]:
# 38  Ses01F_impro02_M003  [052.7100-059.0534]:
# 39  Ses01F_impro02_F005  [058.7500-061.3100]:
# 40  Ses01F_impro02_M004  [061.7500-065.0550]:
# 41  Ses01F_impro02_F006  [064.2550-068.4700]:
# 42  Ses01F_impro02_M005  [069.3400-074.2900]:
# 43  Ses01F_impro02_F007  [072.3900-078.5700]:
# 44  Ses01F_impro02_M006  [080.0300-086.9900]:
# 45  Ses01F_impro02_F008  [087.2031-091.0900]:
# 46  Ses01F_impro02_F009  [091.5500-095.8800]:
# 47  Ses01F_impro02_F010  [097.9400-102.1900]:
# 48  Ses01F_impro02_M007  [103.2700-107.1000]:
# 49  Ses01F_impro02_F011  [107.6800-111.0153]:
#
#                                         Transcription Sentiment  Valence  \
# 0                                          Excuse me.       neu      2.5
# 1                             Do you have your forms?       fru      2.5
# 2                                               Yeah.       neu      2.5
# 3                                    Let me see them.       fru      2.5
# 4                                 Is there a problem?       neu      2.5
# 5                   Who told you to get in this line?       fru      2.0
# 6                                            You did.       xxx      2.5
# 7   You were standing at the beginning and you dir...       xxx      2.5
# 8   Okay. But I didn't tell you to get in this lin...       fru      2.5
# 9         Well what's the problem?  Let me change it.       neu      2.5
# 10                           This form is a Z.X.four.       fru      2.0
# 11  You can't--  This is not the line for Z.X.four...       fru      2.0
# 12  What?  I'm getting an ID.  This is why I'm her...       fru      2.0
# 13  No. I need another set of ID to prove this is ...       fru      2.0
# 14  How am I supposed to get an ID without an ID? ...       fru      2.5
# 15  I don't know.  But I need an ID to pass this f...       fru      2.5
# 16                             I'm here to get an ID.       fru      2.0
# 17            No.  I need another ID, a separate one.       fru      2.0
# 18              Like what?  Like a birth certificate?       fru      2.0
# 19  A birth certificate, a passport...a student ID...       fru      2.5
# 20              Who the hell has a birth certificate?       xxx      1.5
# 21  Yes but my wallet was stolen, I don't have any...       fru      2.0
# 22  Yeah.  We keep it on file, but we need an ID t...       fru      2.0
# 23                             That's out of control.       ang      2.0
# 24  I don't understand why this is so complicated ...       ang      2.0
# 25               How long have you been working here?       fru      2.0
# 26                                 Actually too long.       xxx      3.0
# 27  Clearly.  You know, do you have like a supervi...       neu      2.5
# 28  Yeah.  Do you want to see my supervisor?  Huh?...       ang      2.0
# 29       That would - I would appreciate that.  Yeah.       fru      2.0
# 30        Did you get the mail? So you saw my letter?       sad      2.5
# 31                                     It's not fair.       xxx      2.0
# 32                                     Yeah.  I know.       sad      2.0
# 33  I don't understand.  You've already done so mu...       sad      2.0
# 34  I don't know.  I put in that. request too. The...       sad      2.0
# 35  I guess, you know, everybody has to make sacri...       neu      2.0
# 36  I don't know, it's just not fair.  I think you...       xxx      2.5
# 37  There's people that have given more though, yo...       sad      2.5
# 38  I just don't see how they can make you leave w...       fru      2.0
# 39                                            I know.       sad      2.0
# 40                      Then why is that fair?  Why--       xxx      2.0
# 41  There's babies over there, though, that need m...       neu      2.5
# 42  I don't know how you can be okay with this?  I...       sad      2.0
# 43  I'm not okay with it, but I don't-- it's not l...       xxx      2.0
# 44  I'm just trying to think of another way.  I'm ...       xxx      2.0
# 45                    Just, you know, kicking myself.       sad      1.5
# 46        like you sign up because you need money and       xxx      1.5
# 47                 things just aren't what they seem.       sad      2.0
# 48                              This is a stupid war.       xxx      2.0
# 49               We're doing the right thing, though.       xxx      2.5
#
#     Activation  Dominance
# 0          2.5        2.5
# 1          2.0        2.5
# 2          2.5        2.5
# 3          2.0        2.5
# 4          2.5        2.5
# 5          3.5        3.5
# 6          3.0        3.0
# 7          3.0        2.5
# 8          3.5        3.5
# 9          3.5        2.0
# 10         4.0        3.5
# 11         3.5        3.5
# 12         3.5        3.5
# 13         3.5        3.5
# 14         3.5        3.5
# 15         3.5        3.0
# 16         3.5        3.5
# 17         3.5        3.5
# 18         3.5        3.0
# 19         3.5        4.0
# 20         3.5        3.5
# 21         3.5        3.5
# 22         4.5        4.0
# 23         3.5        3.5
# 24         4.0        4.0
# 25         4.0        3.5
# 26         1.5        2.0
# 27         3.5        3.5
# 28         4.5        4.5
# 29         3.5        3.0
# 30         2.0        1.5
# 31         2.5        2.5
# 32         1.5        1.5
# 33         2.5        2.5
# 34         1.5        1.5
# 35         2.0        2.0
# 36         3.0        2.5
# 37         2.0        2.5
# 38         3.0        3.0
# 39         2.0        2.5
# 40         3.0        2.0
# 41         2.5        2.5
# 42         3.0        1.5
# 43         3.5        3.0
# 44         3.0        1.5
# 45         2.0        1.5
# 46         1.5        2.0
# 47         1.5        2.0
# 48         3.0        2.5
# 49         2.5        2.5

# %%
merged.shape
# Out:
# (10039, 7)

# %%
merged.groupby("Sentiment").count()
# Out:
#            Session_ID  Time_Record  Transcription  Valence  Activation  \
# Sentiment
# ang              1103         1103           1103     1103        1103
# dis                 2            2              2        2           2
# exc              1041         1041           1041     1041        1041
# fea                40           40             40       40          40
# fru              1849         1849           1849     1849        1849
# hap               595          595            595      595         595
# neu              1708         1708           1708     1708        1708
# oth                 3            3              3        3           3
# sad              1084         1084           1084     1084        1084
# sur               107          107            107      107         107
# xxx              2507         2507           2507     2507        2507
#
#            Dominance
# Sentiment
# ang             1103
# dis                2
# exc             1041
# fea               40
# fru             1849
# hap              595
# neu             1708
# oth                3
# sad             1084
# sur              107
# xxx             2507

# %% [markdown]
# # Limpeza dos dados
#
# Analisando os dados previamente, alguns problemas foram detectados:
#     * xxx sentimento indefinido
#     * oth baixa informações
#     * dis baixa informações

# %%
merged = merged[merged['Sentiment'] != "xxx"]
merged = merged[merged['Sentiment'] != 'oth']
merged = merged[merged['Sentiment'] != 'dis']

merged.groupby("Sentiment").count()
# Out:
#            Session_ID  Time_Record  Transcription  Valence  Activation  \
# Sentiment
# ang              1103         1103           1103     1103        1103
# exc              1041         1041           1041     1041        1041
# fea                40           40             40       40          40
# fru              1849         1849           1849     1849        1849
# hap               595          595            595      595         595
# neu              1708         1708           1708     1708        1708
# sad              1084         1084           1084     1084        1084
# sur               107          107            107      107         107
#
#            Dominance
# Sentiment
# ang             1103
# exc             1041
# fea               40
# fru             1849
# hap              595
# neu             1708
# sad             1084
# sur              107

# %% [markdown]
# ### Vamos discretizar os valores dos sentimentos

# %%
def retorna_label(text):
    dici = {"neu":0,"fru":1,"ang":2,"sad":3,"hap":4,"sur":5,"exc":6,"fea":7}
    return dici[text]

# %%
merged['discrete'] = merged['Sentiment'].apply(retorna_label)

# %%
merged.shape
# Out:
# (7527, 8)

# %%
merged.head()
# Out:
#             Session_ID           Time_Record          Transcription Sentiment  \
# 0  Ses01F_impro01_F000  [006.2901-008.2357]:              excuse me       neu
# 1  Ses01F_impro01_M000  [007.5712-010.4750]:  do you have your form       fru
# 2  Ses01F_impro01_F001  [010.0100-011.3925]:                   yeah       neu
# 3  Ses01F_impro01_M001  [010.9266-014.6649]:        let me see them       fru
# 4  Ses01F_impro01_F002  [014.8872-018.0175]:     is there a problem       neu
#
#    Valence  Activation  Dominance  discrete
# 0      2.5         2.5        2.5         0
# 1      2.5         2.0        2.5         1
# 2      2.5         2.5        2.5         0
# 3      2.5         2.0        2.5         1
# 4      2.5         2.5        2.5         0

# %%
merged.describe().T
# Out:
#              count      mean       std  min  25%  50%  75%  max
# Valence     7527.0  2.745450  0.908585  1.0  2.0  2.5  3.5  5.5
# Activation  7527.0  3.107181  0.724216  1.0  2.5  3.0  3.5  5.0
# Dominance   7527.0  3.199205  0.803800  0.5  2.5  3.0  4.0  5.0
# discrete    7527.0  2.225056  2.009238  0.0  1.0  2.0  3.0  7.0

# %%
merged.corr()
# Out:
#              Valence  Activation  Dominance  discrete
# Valence     1.000000    0.003217  -0.197505  0.436825
# Activation  0.003217    1.000000   0.570118  0.238117
# Dominance  -0.197505    0.570118   1.000000  0.071766
# discrete    0.436825    0.238117   0.071766  1.000000

# %%
correlation = merged.corr(method='pearson')


mask = np.zeros_like(correlation)
mask[np.triu_indices_from(mask)] = True

fig, ax = plt.subplots()
ax.set_title("Correlação entre as variaveis independentes com a variável dependente")
ax.figure.set_size_inches(10,10)
sns.heatmap(correlation, ax=ax, annot=True, mask=mask, fmt='.2f', cbar=True, square=True, cmap=plt.cm.Blues, center=0.1)

# %%
merged.to_csv("dadosMerged.csv",index=False)

# %% [markdown]
# # Pré-Processamento

# %%
import nltk
nltk.download('stopwords')
from sklearn import re #regular expression for text processing
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer #word stemmer class
lemma = WordNetLemmatizer()
#from wordcloud import WordCloud, STOPWORDS
from nltk import FreqDist 
# vectorizer 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression #classification model
from sklearn.metrics import confusion_matrix, classification_report, f1_score # performance evaluation criteria
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/matheus/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def normalizer(tweet):
    tweets = " ".join(filter(lambda x: x[0]!= '@' , tweet.split()))
    tweets = re.sub('[^a-zA-Z]', ' ', tweets)
    tweets = tweets.lower()
    tweets = tweets.split()
    tweets = [word for word in tweets if not word in set(stopwords.words('english'))]
    #tweets = [lemma.lemmatize(word) for word in tweets]
    tweets = " ".join(tweets)
    return tweets

# %%
merged['Transcription'] = merged.Transcription.apply(normalizer) #não obteve melhoras com a normalização dos dados

# %%
merged.head()
# Out:
#             Session_ID           Time_Record Transcription Sentiment  Valence  \
# 0  Ses01F_impro01_F000  [006.2901-008.2357]:        excuse       neu      2.5
# 1  Ses01F_impro01_M000  [007.5712-010.4750]:          form       fru      2.5
# 2  Ses01F_impro01_F001  [010.0100-011.3925]:          yeah       neu      2.5
# 3  Ses01F_impro01_M001  [010.9266-014.6649]:       let see       fru      2.5
# 4  Ses01F_impro01_F002  [014.8872-018.0175]:       problem       neu      2.5
#
#    Activation  Dominance  discrete
# 0         2.5        2.5         0
# 1         2.0        2.5         1
# 2         2.5        2.5         0
# 3         2.0        2.5         1
# 4         2.5        2.5         0

# %%
def plot_LSA(test_data, test_labels, savepath="PCA_demo.csv", plot=True):
        lsa = TruncatedSVD(n_components=2)
        lsa.fit(test_data)
        lsa_scores = lsa.transform(test_data)
        color_mapper = {label:idx for idx,label in enumerate(set(test_labels))}
        color_column = [color_mapper[label] for label in test_labels]
        colors = ['orange','blue',"yellow","beige","black","brown","gray","red"]
        if plot:
            #dici = {"neu":0,"fru":1,"ang":2,"sad":3,"hap":4,"sur":5,"exc":6,"fea":7}
            plt.scatter(lsa_scores[:,0], lsa_scores[:,1], s=8, alpha=.8, c=test_labels, cmap=matplotlib.colors.ListedColormap(colors))
            oran_patch = mpatches.Patch(color = 'orange',label = 'neutral')
            blue_patch = mpatches.Patch(color = 'blue',label = 'frustrated')
            yellow_patch = mpatches.Patch(color='yellow',label="angry")
            beige_patch = mpatches.Patch(color = "beige",label = "sad")
            black_patch = mpatches.Patch(color = "black", label = "happy")
            brown_patch = mpatches.Patch(color = "brown", label = "suprised")
            gray_patch = mpatches.Patch(color = "gray", label = "excited")
            red_patch = mpatches.Path(color = "red", label = "fearful")
            plt.legend(handles=[oran_patch, blue_patch,yellow_patch,beige_patch,black_patch,brown_patch,gray_patch,red_patch], prop={'size': 30})

# %%
corpus_train, corpus_test, y_train, y_test = train_test_split(merged.Transcription, merged.discrete, test_size=0.2, random_state=7)
vectorizer = CountVectorizer(ngram_range = (1, 3))
X_train = vectorizer.fit_transform(corpus_train)
X_test = vectorizer.transform(corpus_test)

# %%
fig = plt.figure(figsize=(16, 16))    
plot_LSA(X_train,y_train)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# ## Modelo : Regressão Linear

# %%
X = merged['Transcription']
Y = merged['Sentiment']

# %%
model = LogisticRegression(penalty="l2", C=1.0)
model.fit(X_train, y_train)
# Out:
# /home/matheus/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/matheus/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred = model.predict(X_test)
print("Precisão: ",accuracy_score(y_test,pred))
# Out:
# Precisão:  0.5590969455511288

# %% [markdown]
# ### Vamos tentar prever o sentimentos por meio de deep learning.
