# %%
import pandas as pd
import gensim
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("avaliText.csv")

data
# Out:
#       avaliacao                                               twet  \
# 0       neutral                                        what  said.
# 1      positive   plus you've added commercials to the experien...
# 2       neutral   i didn't today... must mean i need to take an...
# 3      negative   it's really aggressive to blast obnoxious "en...
# 4      negative           and it's a really big bad thing about it
# ...         ...                                                ...
# 14635  positive   thank you we got on a different flight to chi...
# 14636  negative   leaving over 20 minutes late flight. no warni...
# 14637   neutral                 please bring american airlines to
# 14638  negative   you have my money, you change my flight, and ...
# 14639   neutral   we have 8 ppl so we need 2 know how many seat...
#
#        class_label
# 0                0
# 1                1
# 2                0
# 3               -1
# 4               -1
# ...            ...
# 14635            1
# 14636           -1
# 14637            0
# 14638           -1
# 14639            0
#
# [14640 rows x 3 columns]

# %%
def read_questions(row,column_name):
    return gensim.utils.simple_preprocess(str(row[column_name]).encode('utf-8'))

documents = []
for index, row in data.iterrows():
    documents.append(read_questions(row,"twet"))

# %%
documents
# Out:
# [['what', 'said'],
#  ['plus',
#   'you',
#   've',
#   'added',
#   'commercials',
#   'to',
#   'the',
#   'experience',
#   'tacky'],
#  ['didn', 'today', 'must', 'mean', 'need', 'to', 'take', 'another', 'trip'],
#  ['it',
#   'really',
#   'aggressive',
#   'to',
#   'blast',
#   'obnoxious',
#   'entertainment',
#   'in',
#   'your',
#   'guests',
#   'faces',
#   'amp',
#   'they',
#   'have',
#   'little',
#   'recourse'],
#  ['and', 'it', 'really', 'big', 'bad', 'thing', 'about', 'it'],
#  ['seriously',
#   'would',
#   'pay',
#   'flight',
#   'for',
#   'seats',
#   'that',
#   'didn',
#   'have',
#   'this',
#   'playing',
#   'it',
#   'really',
#   'the',
#   'only',
#   'bad',
#   'thing',
#   'about',
#   'flying',
#   'va'],
#  ['yes',
#   'nearly',
#   'every',
#   'time',
#   'fly',
#   'vx',
#   'this',
#   'ear',
#   'worm',
#   'won',
#   'go',
#   'away'],
#  ['really',
#   'missed',
#   'prime',
#   'opportunity',
#   'for',
#   'men',
#   'without',
#   'hats',
#   'parody',
#   'there'],
#  ['well', 'didn', 'but', 'now', 'do'],
#  ['it',
#   'was',
#   'amazing',
#   'and',
#   'arrived',
#   'an',
#   'hour',
#   'early',
#   'you',
#   're',
#   'too',
#   'good',
#   'to',
#   'me'],
#  ['did',
#   'you',
#   'know',
#   'that',
#   'suicide',
#   'is',
#   'the',
#   'second',
#   'leading',
#   'cause',
#   'of',
#   'death',
#   'among',
#   'teens'],
#  ['lt',
#   'pretty',
#   'graphics',
#   'so',
#   'much',
#   'better',
#   'than',
#   'minimal',
#   'iconography'],
#  ['this',
#   'is',
#   'such',
#   'great',
#   'deal',
#   'already',
#   'thinking',
#   'about',
#   'my',
#   'nd',
#   'trip',
#   'to',
#   'amp',
#   'haven',
#   'even',
#   'gone',
#   'on',
#   'my',
#   'st',
#   'trip',
#   'yet'],
#  ['flying',
#   'your',
#   'skies',
#   'again',
#   'take',
#   'all',
#   'the',
#   'away',
#   'from',
#   'travel'],
#  ['thanks'],
#  ['sfo', 'pdx', 'schedule', 'is', 'still', 'mia'],
#  ['so',
#   'excited',
#   'for',
#   'my',
#   'first',
#   'cross',
#   'country',
#   'flight',
#   'lax',
#   'to',
#   'mco',
#   've',
#   'heard',
#   'nothing',
#   'but',
#   'great',
#   'things',
#   'about',
#   'virgin',
#   'america'],
#  ['flew',
#   'from',
#   'nyc',
#   'to',
#   'sfo',
#   'last',
#   'week',
#   'and',
#   'couldn',
#   'fully',
#   'sit',
#   'in',
#   'my',
#   'seat',
#   'due',
#   'to',
#   'two',
#   'large',
#   'gentleman',
#   'on',
#   'either',
#   'side',
#   'of',
#   'me',
#   'help'],
#  ['flying'],
#  ['you',
#   'know',
#   'what',
#   'would',
#   'be',
#   'amazingly',
#   'awesome',
#   'bos',
#   'fll',
#   'please',
#   'want',
#   'to',
#   'fly',
#   'with',
#   'only',
#   'you'],
#  ['why',
#   'are',
#   'your',
#   'first',
#   'fares',
#   'in',
#   'may',
#   'over',
#   'three',
#   'times',
#   'more',
#   'than',
#   'other',
#   'carriers',
#   'when',
#   'all',
#   'seats',
#   'are',
#   'available',
#   'to',
#   'select'],
#  ['love', 'this', 'graphic'],
#  ['love',
#   'the',
#   'hipster',
#   'innovation',
#   'you',
#   'are',
#   'feel',
#   'good',
#   'brand'],
#  ['will',
#   'you',
#   'be',
#   'making',
#   'bos',
#   'gt',
#   'las',
#   'non',
#   'stop',
#   'permanently',
#   'anytime',
#   'soon'],
#  ['you',
#   'guys',
#   'messed',
#   'up',
#   'my',
#   'seating',
#   'reserved',
#   'seating',
#   'with',
#   'my',
#   'friends',
#   'and',
#   'you',
#   'guys',
#   'gave',
#   'my',
#   'seat',
#   'away',
#   'want',
#   'free',
#   'internet'],
#  ['status',
#   'match',
#   'program',
#   'applied',
#   'and',
#   'it',
#   'been',
#   'three',
#   'weeks',
#   'called',
#   'and',
#   'emailed',
#   'with',
#   'no',
#   'response'],
#  ['what',
#   'happened',
#   'ur',
#   'vegan',
#   'food',
#   'options',
#   'at',
#   'least',
#   'say',
#   'on',
#   'ur',
#   'site',
#   'so',
#   'know',
#   'won',
#   'be',
#   'able',
#   'eat',
#   'anything',
#   'for',
#   'next',
#   'hrs'],
#  ['do',
#   'you',
#   'miss',
#   'me',
#   'don',
#   'worry',
#   'we',
#   'll',
#   'be',
#   'together',
#   'very',
#   'soon'],
#  ['amazing',
#   'to',
#   'me',
#   'that',
#   'we',
#   'can',
#   'get',
#   'any',
#   'cold',
#   'air',
#   'from',
#   'the',
#   'vents'],
#  ['lax',
#   'to',
#   'ewr',
#   'middle',
#   'seat',
#   'on',
#   'red',
#   'eye',
#   'such',
#   'noob',
#   'maneuver'],
#  ['hi',
#   'just',
#   'bked',
#   'cool',
#   'birthday',
#   'trip',
#   'with',
#   'you',
#   'but',
#   'can',
#   'add',
#   'my',
#   'elevate',
#   'no',
#   'cause',
#   'entered',
#   'my',
#   'middle',
#   'name',
#   'during',
#   'flight',
#   'booking',
#   'problems'],
#  ['are',
#   'the',
#   'hours',
#   'of',
#   'operation',
#   'for',
#   'the',
#   'club',
#   'at',
#   'sfo',
#   'that',
#   'are',
#   'posted',
#   'online',
#   'current'],
#  ['help',
#   'left',
#   'expensive',
#   'headphones',
#   'on',
#   'flight',
#   'iad',
#   'to',
#   'lax',
#   'today',
#   'seat',
#   'no',
#   'one',
#   'answering',
#   'amp',
#   'number',
#   'at',
#   'lax'],
#  ['awaiting',
#   'my',
#   'return',
#   'phone',
#   'call',
#   'just',
#   'would',
#   'prefer',
#   'to',
#   'use',
#   'your',
#   'online',
#   'self',
#   'service',
#   'option'],
#  ['this',
#   'is',
#   'great',
#   'news',
#   'america',
#   'could',
#   'start',
#   'flights',
#   'to',
#   'hawaii',
#   'by',
#   'end',
#   'of',
#   'year',
#   'via'],
#  ['nice',
#   'rt',
#   'vibe',
#   'with',
#   'the',
#   'moodlight',
#   'from',
#   'takeoff',
#   'to',
#   'touchdown'],
#  ['moodlighting',
#   'is',
#   'the',
#   'only',
#   'way',
#   'to',
#   'fly',
#   'best',
#   'experience',
#   'ever',
#   'cool',
#   'and',
#   'calming'],
#  ['done', 'and', 'done', 'best', 'airline', 'around', 'hands', 'down'],
#  ['when', 'can', 'book', 'my', 'flight', 'to', 'hawaii'],
#  ['your', 'chat', 'support', 'is', 'not', 'working', 'on', 'your', 'site'],
#  ['view',
#   'of',
#   'downtown',
#   'los',
#   'angeles',
#   'the',
#   'hollywood',
#   'sign',
#   'and',
#   'beyond',
#   'that',
#   'rain',
#   'in',
#   'the',
#   'mountains'],
#  ['hey',
#   'first',
#   'time',
#   'flyer',
#   'next',
#   'week',
#   'excited',
#   'but',
#   'having',
#   'hard',
#   'time',
#   'getting',
#   'my',
#   'flights',
#   'added',
#   'to',
#   'my',
#   'elevate',
#   'account',
#   'help'],
#  ['plz',
#   'help',
#   'me',
#   'win',
#   'my',
#   'bid',
#   'upgrade',
#   'for',
#   'my',
#   'flight',
#   'lax',
#   'gt',
#   'sea'],
#  ['have',
#   'an',
#   'unused',
#   'ticket',
#   'but',
#   'moved',
#   'to',
#   'new',
#   'city',
#   'where',
#   'you',
#   'don',
#   'fly',
#   'how',
#   'can',
#   'fly',
#   'with',
#   'you',
#   'before',
#   'it',
#   'expires'],
#  ['are',
#   'flights',
#   'leaving',
#   'dallas',
#   'for',
#   'seattle',
#   'on',
#   'time',
#   'feb'],
#  ['for', 'good', 'reason', 'you', 'rock'],
#  ['dream'],
#  ['wow', 'this', 'just', 'blew', 'my', 'mind'],
#  ['after', 'last', 'night', 'think', 'agree'],
#  ['all', 'were', 'entertaining'],
#  ['is',
#   'flight',
#   'on',
#   'it',
#   'way',
#   'was',
#   'supposed',
#   'to',
#   'take',
#   'off',
#   'minutes',
#   'ago',
#   'website',
#   'still',
#   'shows',
#   'on',
#   'time',
#   'not',
#   'in',
#   'flight',
#   'thanks'],
#  ['julie',
#   'andrews',
#   'all',
#   'the',
#   'way',
#   'though',
#   'was',
#   'very',
#   'impressive',
#   'no',
#   'to'],
#  ['wish', 'you', 'flew', 'out', 'of', 'atlanta', 'soon'],
#  ['julie', 'andrews', 'hands', 'down'],
#  ['will',
#   'flights',
#   'be',
#   'leaving',
#   'dallas',
#   'for',
#   'la',
#   'on',
#   'february',
#   'th'],
#  ['hi',
#   'so',
#   'excited',
#   'about',
#   'your',
#   'lga',
#   'gt',
#   'dal',
#   'deal',
#   'but',
#   've',
#   'been',
#   'trying',
#   'book',
#   'since',
#   'last',
#   'week',
#   'amp',
#   'the',
#   'page',
#   'never',
#   'loads',
#   'thx'],
#  ['you', 'know', 'it', 'need', 'it', 'on', 'my', 'spotify', 'stat'],
#  ['lady', 'gaga', 'she', 'is', 'amazing'],
#  ['carrie'],
#  ['new', 'marketing', 'song', 'let', 'us', 'know', 'what', 'you', 'think'],
#  ['julie',
#   'andrews',
#   'first',
#   'but',
#   'lady',
#   'gaga',
#   'wow',
#   'me',
#   'last',
#   'night',
#   'carrie',
#   'meh'],
#  ['called',
#   'weeks',
#   'ago',
#   'about',
#   'adding',
#   'flights',
#   'from',
#   'to',
#   'my',
#   'elevate',
#   'they',
#   'still',
#   'haven',
#   'shown',
#   'up',
#   'help'],
#  ['all', 'are', 'great', 'but', 'have', 'to', 'go', 'with'],
#  ['sorry', 'mary', 'martin', 'had', 'it', 'first'],
#  ['love',
#   'all',
#   'three',
#   'but',
#   'you',
#   'really',
#   'can',
#   'beat',
#   'the',
#   'classics'],
#  ['flight',
#   'dal',
#   'to',
#   'dca',
#   'pm',
#   'tried',
#   'to',
#   'check',
#   'in',
#   'could',
#   'not',
#   'status',
#   'please'],
#  ['heyyyy',
#   'guyyyys',
#   'been',
#   'trying',
#   'to',
#   'get',
#   'through',
#   'for',
#   'an',
#   'hour',
#   'can',
#   'someone',
#   'call',
#   'me',
#   'please'],
#  ['hi',
#   'virgin',
#   'on',
#   'hold',
#   'for',
#   'minutes',
#   'are',
#   'there',
#   'any',
#   'earlier',
#   'flights',
#   'from',
#   'la',
#   'to',
#   'nyc',
#   'tonight',
#   'earlier',
#   'than',
#   'pm'],
#  ['congrats',
#   'on',
#   'winning',
#   'the',
#   'award',
#   'for',
#   'best',
#   'deals',
#   'from',
#   'an',
#   'airline',
#   'us'],
#  ['everything', 'was', 'fine', 'until', 'you', 'lost', 'my', 'bag'],
#  ['need',
#   'to',
#   'change',
#   'reservation',
#   'have',
#   'virgin',
#   'credit',
#   'card',
#   'do',
#   'need',
#   'to',
#   'modify',
#   'on',
#   'phone',
#   'to',
#   'waive',
#   'change',
#   'fee',
#   'or',
#   'can',
#   'do',
#   'online'],
#  ['emailed',
#   'your',
#   'customer',
#   'service',
#   'team',
#   'let',
#   'me',
#   'know',
#   'if',
#   'you',
#   'need',
#   'the',
#   'tracking',
#   'number'],
#  ['hi',
#   'just',
#   'booked',
#   'flight',
#   'but',
#   'need',
#   'to',
#   'add',
#   'baggage',
#   'how',
#   'can',
#   'do',
#   'this'],
#  ['your',
#   'airline',
#   'is',
#   'awesome',
#   'but',
#   'your',
#   'lax',
#   'loft',
#   'needs',
#   'to',
#   'step',
#   'up',
#   'its',
#   'game',
#   'for',
#   'dirty',
#   'tables',
#   'and',
#   'floors'],
#  ['not',
#   'worried',
#   'it',
#   'been',
#   'great',
#   'ride',
#   'in',
#   'new',
#   'plane',
#   'with',
#   'great',
#   'crew',
#   'all',
#   'airlines',
#   'should',
#   'be',
#   'like',
#   'this'],
#  ['awesome',
#   'flew',
#   'yall',
#   'sat',
#   'morning',
#   'any',
#   'way',
#   'we',
#   'can',
#   'correct',
#   'my',
#   'bill'],
#  ['or',
#   'watch',
#   'some',
#   'of',
#   'the',
#   'best',
#   'student',
#   'films',
#   'in',
#   'the',
#   'country',
#   'at',
#   'feet'],
#  ['first',
#   'time',
#   'flying',
#   'you',
#   'all',
#   'do',
#   'you',
#   'have',
#   'different',
#   'rate',
#   'policy',
#   'for',
#   'media',
#   'bags',
#   'thanks'],
#  ['what',
#   'is',
#   'going',
#   'on',
#   'with',
#   'customer',
#   'service',
#   'is',
#   'there',
#   'anyway',
#   'to',
#   'speak',
#   'to',
#   'human',
#   'asap',
#   'thank',
#   'you'],
#  ['what', 'happened', 'to', 'doom'],
#  ['why',
#   'can',
#   'you',
#   'supp',
#   'the',
#   'biz',
#   'traveler',
#   'like',
#   'and',
#   'have',
#   'customer',
#   'service',
#   'like'],
#  ['ve',
#   'applied',
#   'more',
#   'then',
#   'once',
#   'to',
#   'be',
#   'member',
#   'of',
#   'the',
#   'crew',
#   'team',
#   'im',
#   'interested'],
#  ['you',
#   're',
#   'the',
#   'best',
#   'whenever',
#   'begrudgingly',
#   'use',
#   'any',
#   'other',
#   'airline',
#   'delayed',
#   'and',
#   'late',
#   'flight'],
#  ['have',
#   'no',
#   'interesting',
#   'flying',
#   'with',
#   'you',
#   'after',
#   'this',
#   'will',
#   'cancelled',
#   'flight',
#   'my',
#   'next',
#   'four',
#   'flights',
#   'planned'],
#  ['it',
#   'was',
#   'disappointing',
#   'experience',
#   'which',
#   'will',
#   'be',
#   'shared',
#   'with',
#   'every',
#   'business',
#   'traveler',
#   'meet'],
#  ['having',
#   'trouble',
#   'adding',
#   'this',
#   'flight',
#   'my',
#   'wife',
#   'booked',
#   'to',
#   'my',
#   'elevate',
#   'account',
#   'help'],
#  ['can',
#   'bring',
#   'up',
#   'my',
#   'reservation',
#   'online',
#   'using',
#   'flight',
#   'booking',
#   'problems',
#   'code'],
#  ['random',
#   'what',
#   'the',
#   'distribution',
#   'of',
#   'elevate',
#   'avatars',
#   'bet',
#   'that',
#   'kitty',
#   'has',
#   'share'],
#  ['lt',
#   'flying',
#   'va',
#   'but',
#   'life',
#   'happens',
#   'and',
#   'am',
#   'trying',
#   'to',
#   'my',
#   'trip',
#   'jperhi',
#   'can',
#   'you',
#   'help',
#   'va',
#   'home',
#   'page',
#   'will',
#   'not',
#   'let',
#   'me'],
#  ['why',
#   'is',
#   'the',
#   'site',
#   'down',
#   'when',
#   'will',
#   'it',
#   'be',
#   'back',
#   'up'],
#  ['you', 'down', 'with', 'rnp', 'yeah', 'you', 'know', 'me'],
#  ['hi',
#   'did',
#   'not',
#   'get',
#   'points',
#   'on',
#   'my',
#   'elevate',
#   'account',
#   'for',
#   'my',
#   'most',
#   'recent',
#   'flight',
#   'how',
#   'do',
#   'add',
#   'the',
#   'flight',
#   'and',
#   'points',
#   'to',
#   'my',
#   'account'],
#  ['like',
#   'the',
#   'tv',
#   'and',
#   'interesting',
#   'video',
#   'just',
#   'disappointed',
#   'in',
#   'cancelled',
#   'flightled',
#   'flight',
#   'when',
#   'other',
#   'flights',
#   'went',
#   'out',
#   'to',
#   'jfk',
#   'on',
#   'saturday'],
#  ['just',
#   'landed',
#   'in',
#   'lax',
#   'an',
#   'hour',
#   'after',
#   'should',
#   'of',
#   'been',
#   'here',
#   'your',
#   'no',
#   'late',
#   'flight',
#   'bag',
#   'check',
#   'is',
#   'not',
#   'business',
#   'travel',
#   'friendly'],
#  ['why', 'is', 'flight', 'redirected'],
#  ['is',
#   'it',
#   'me',
#   'or',
#   'is',
#   'your',
#   'website',
#   'down',
#   'btw',
#   'your',
#   'new',
#   'website',
#   'isn',
#   'great',
#   'user',
#   'experience',
#   'time',
#   'for',
#   'another',
#   'redesign'],
#  ['can',
#   'check',
#   'in',
#   'or',
#   'add',
#   'bag',
#   'your',
#   'website',
#   'isn',
#   'working',
#   've',
#   'tried',
#   'both',
#   'desktop',
#   'and',
#   'mobile'],
#  ['let',
#   'scanned',
#   'in',
#   'passengers',
#   'leave',
#   'the',
#   'plane',
#   'than',
#   'told',
#   'someone',
#   'to',
#   'remove',
#   'their',
#   'bag',
#   'from',
#   'st',
#   'class',
#   'bin'],
#  ['what',
#   'is',
#   'your',
#   'phone',
#   'number',
#   'can',
#   'find',
#   'who',
#   'to',
#   'call',
#   'about',
#   'flight',
#   'reservation'],
#  ['is',
#   'anyone',
#   'doing',
#   'anything',
#   'there',
#   'today',
#   'website',
#   'is',
#   'useless',
#   'and',
#   'no',
#   'one',
#   'is',
#   'answering',
#   'the',
#   'phone'],
#  ['trying',
#   'to',
#   'add',
#   'my',
#   'boy',
#   'prince',
#   'to',
#   'my',
#   'ressie',
#   'sf',
#   'this',
#   'thursday',
#   'from',
#   'lax'],
#  ['why',
#   'must',
#   'traveler',
#   'miss',
#   'flight',
#   'to',
#   'late',
#   'flight',
#   'check',
#   'bag',
#   'missed',
#   'my',
#   'morning',
#   'appointments',
#   'and',
#   'you',
#   'lost',
#   'my',
#   'business'],
#  ['check', 'out', 'new', 'music'],
#  ['how',
#   'direct',
#   'flight',
#   'fll',
#   'gt',
#   'sfo',
#   'have',
#   'unexpected',
#   'layover',
#   'in',
#   'vegas',
#   'fuel',
#   'yet',
#   'peeps',
#   'next',
#   'to',
#   'me',
#   'bought',
#   'for',
#   'vegas',
#   'flight'],
#  ['your',
#   'no',
#   'late',
#   'flight',
#   'bag',
#   'check',
#   'just',
#   'lost',
#   'you',
#   'my',
#   'business',
#   'missed',
#   'flight',
#   'and',
#   'am',
#   'apt',
#   'three',
#   'other',
#   'people',
#   'on',
#   'flight',
#   'had',
#   'same',
#   'exp'],
#  ['amazing',
#   'customer',
#   'service',
#   'again',
#   'raeann',
#   'in',
#   'sf',
#   'she',
#   'the',
#   'best'],
#  ['called',
#   'your',
#   'service',
#   'line',
#   'and',
#   'was',
#   'hung',
#   'up',
#   'on',
#   'this',
#   'is',
#   'awesome'],
#  ['your',
#   'site',
#   'is',
#   'tripping',
#   'trying',
#   'to',
#   'check',
#   'in',
#   'and',
#   'getting',
#   'the',
#   'plain',
#   'text',
#   'version',
#   'am',
#   'reluctant',
#   'to',
#   'enter',
#   'any',
#   'card',
#   'info'],
#  ['was',
#   'scheduled',
#   'for',
#   'sfo',
#   'dal',
#   'flight',
#   'today',
#   'changed',
#   'to',
#   'th',
#   'due',
#   'weather',
#   'looks',
#   'like',
#   'flight',
#   'still',
#   'on'],
#  ['has',
#   'getaway',
#   'deals',
#   'through',
#   'may',
#   'from',
#   'one',
#   'way',
#   'lots',
#   'of',
#   'cool',
#   'cities'],
#  ['has',
#   'getaway',
#   'deals',
#   'through',
#   'may',
#   'from',
#   'one',
#   'way',
#   'lots',
#   'of',
#   'cool',
#   'cities'],
#  ['has',
#   'getaway',
#   'deals',
#   'through',
#   'may',
#   'from',
#   'one',
#   'way',
#   'lots',
#   'of',
#   'cool',
#   'cities'],
#  ['has',
#   'getaway',
#   'deals',
#   'through',
#   'may',
#   'from',
#   'one',
#   'way',
#   'lots',
#   'of',
#   'cool',
#   'cities'],
#  ['have', 'great', 'week'],
#  ['come',
#   'back',
#   'to',
#   'already',
#   'we',
#   'need',
#   'you',
#   'to',
#   'take',
#   'us',
#   'out',
#   'of',
#   'this',
#   'horrible',
#   'cold'],
#  ['should',
#   'be',
#   'concerned',
#   'that',
#   'am',
#   'about',
#   'to',
#   'fly',
#   'on',
#   'plane',
#   'that',
#   'needs',
#   'to',
#   'be',
#   'delayed',
#   'due',
#   'to',
#   'tech',
#   'stop'],
#  ['is',
#   'the',
#   'best',
#   'airline',
#   'have',
#   'flown',
#   'on',
#   'easy',
#   'to',
#   'change',
#   'your',
#   'reservation',
#   'helpful',
#   'representatives',
#   'amp',
#   'comfortable',
#   'flying',
#   'experience'],
#  ['and',
#   'again',
#   'another',
#   'rep',
#   'kicked',
#   'butt',
#   'naelah',
#   'represents',
#   'your',
#   'team',
#   'so',
#   'beautifully',
#   'thank',
#   'you'],
#  ['your',
#   'beautiful',
#   'front',
#   'end',
#   'design',
#   'is',
#   'down',
#   'right',
#   'now',
#   'but',
#   'it',
#   'was',
#   'cool',
#   'to',
#   'still',
#   'book',
#   'my',
#   'ticket',
#   'all',
#   'your',
#   'back',
#   'end',
#   'was',
#   'secure'],
#  ['love',
#   'the',
#   'team',
#   'running',
#   'gate',
#   'at',
#   'las',
#   'tonight',
#   'waited',
#   'for',
#   'delayed',
#   'flight',
#   'and',
#   'they',
#   'kept',
#   'things',
#   'entertaining'],
#  ['use',
#   'another',
#   'browser',
#   'amp',
#   'brand',
#   'with',
#   'reputation',
#   'built',
#   'on',
#   'tech',
#   'response',
#   'doesn',
#   'have',
#   'cross',
#   'browser',
#   'compatible',
#   'website'],
#  ['and',
#   'now',
#   'the',
#   'flight',
#   'flight',
#   'booking',
#   'problems',
#   'site',
#   'is',
#   'totally',
#   'down',
#   'folks',
#   'what',
#   'is',
#   'the',
#   'problem'],
#  ['like',
#   'the',
#   'customer',
#   'service',
#   'but',
#   'min',
#   'delay',
#   'just',
#   'for',
#   'connecting',
#   'passengers',
#   'seems',
#   'too',
#   'long',
#   'va'],
#  ['thanks',
#   'to',
#   'your',
#   'outstanding',
#   'nyc',
#   'jfk',
#   'crew',
#   'who',
#   'moved',
#   'mountains',
#   'to',
#   'get',
#   'me',
#   'home',
#   'to',
#   'san',
#   'francisco',
#   'tonight'],
#  ['you',
#   'have',
#   'the',
#   'absolute',
#   'best',
#   'team',
#   'and',
#   'customer',
#   'service',
#   'ever',
#   'every',
#   'time',
#   'fly',
#   'with',
#   'you',
#   'delighted',
#   'thank',
#   'you'],
#  ['do',
#   'you',
#   'provide',
#   'complimentary',
#   'upgrades',
#   'to',
#   'first',
#   'class',
#   'if',
#   'there',
#   'are',
#   'available',
#   'seats'],
#  ['need',
#   'to',
#   'change',
#   'my',
#   'flight',
#   'thats',
#   'scheduled',
#   'in',
#   'hours',
#   'and',
#   'min',
#   'wait',
#   'time',
#   'on',
#   'phone',
#   'im',
#   'calling',
#   'intern',
#   'help'],
#  ['completely',
#   'awesome',
#   'experience',
#   'last',
#   'month',
#   'bos',
#   'las',
#   'nonstop',
#   'thanks',
#   'for',
#   'such',
#   'an',
#   'awesome',
#   'flight',
#   'and',
#   'depart',
#   'time'],
#  ['how', 'can', 'watch', 'the', 'on', 'my', 'jfk', 'gt', 'sfo', 'flight'],
#  ['is',
#   'flight',
#   'cancelled',
#   'flightled',
#   'and',
#   'what',
#   'do',
#   'do',
#   'if',
#   'it',
#   'is'],
#  ['you',
#   'are',
#   'failing',
#   'your',
#   'customers',
#   'because',
#   'your',
#   'check',
#   'in',
#   'process',
#   'does',
#   'not',
#   'link',
#   'to',
#   'tsa',
#   'pre',
#   'check'],
#  ['us',
#   'too',
#   'terrible',
#   'airline',
#   'just',
#   'gave',
#   'us',
#   'hotel',
#   'hotline',
#   'number',
#   'and',
#   'said',
#   'sorry'],
#  ['has',
#   'flight',
#   'number',
#   'from',
#   'sfo',
#   'to',
#   'cabo',
#   'san',
#   'lucas',
#   'arrived',
#   'yet'],
#  ['your',
#   'assistance',
#   'yesterday',
#   'when',
#   'cancelled',
#   'flightled',
#   'our',
#   'flight',
#   'was',
#   'to',
#   'give',
#   'us',
#   'hotel',
#   'hotline',
#   'shame',
#   'on',
#   'you'],
#  ['another', 'delayed', 'flight'],
#  ['need',
#   'to',
#   'register',
#   'service',
#   'dog',
#   'for',
#   'first',
#   'class',
#   'ticket',
#   'from',
#   'sfo',
#   'gt',
#   'dulles',
#   'the',
#   'phone',
#   'queue',
#   'is',
#   'an',
#   'hour',
#   'or',
#   'longer',
#   'pls',
#   'advise'],
#  ['you',
#   'rock',
#   'for',
#   'making',
#   'it',
#   'so',
#   'can',
#   'watch',
#   'on',
#   'my',
#   'flight'],
#  ['dropped', 'track', 'on', 'you'],
#  ['always', 'xoxo'],
#  ['why',
#   'can',
#   'we',
#   'book',
#   'seats',
#   'on',
#   'your',
#   'flights',
#   'when',
#   'we',
#   'buy',
#   'them',
#   'or',
#   'even',
#   'during',
#   'check',
#   'in',
#   'creates',
#   'so',
#   'much',
#   'anxiety'],
#  ['you',
#   'think',
#   'paying',
#   'an',
#   'extra',
#   'bucks',
#   'rt',
#   'for',
#   'luggage',
#   'might',
#   'afford',
#   'you',
#   'hiring',
#   'an',
#   'extra',
#   'hand',
#   'at'],
#  ['best',
#   'customer',
#   'service',
#   'rep',
#   'in',
#   'the',
#   'world',
#   'takes',
#   'the',
#   'cake'],
#  ['can',
#   'you',
#   'find',
#   'us',
#   'flt',
#   'out',
#   'of',
#   'lax',
#   'that',
#   'is',
#   'sooner',
#   'than',
#   'midnight',
#   'on',
#   'monday',
#   'that',
#   'would',
#   'be',
#   'great',
#   'customer',
#   'service'],
#  ['please',
#   'provide',
#   'status',
#   'for',
#   'flight',
#   'cant',
#   'imagine',
#   'it',
#   'on',
#   'time',
#   'as',
#   'the',
#   'web',
#   'indicates',
#   'dude',
#   'to',
#   'weather',
#   'here',
#   'and',
#   'or',
#   'dallas'],
#  ['you',
#   'have',
#   'amazing',
#   'staff',
#   'amp',
#   'super',
#   'helpful',
#   'as',
#   'just',
#   'ran',
#   'the',
#   'they',
#   'have',
#   'spoiled',
#   'me',
#   'with',
#   'comfort'],
#  ['paid',
#   'the',
#   'premium',
#   'to',
#   'fly',
#   'you',
#   'across',
#   'the',
#   'country',
#   'you',
#   'cancelled',
#   'flight',
#   'my',
#   'flight',
#   'and',
#   'offer',
#   'no',
#   'check',
#   'fee',
#   'or',
#   'upgrade',
#   'love',
#   'sad',
#   'face'],
#  ['question',
#   'is',
#   'it',
#   'not',
#   'possible',
#   'to',
#   'book',
#   'seat',
#   'for',
#   'an',
#   'infant',
#   'under',
#   'it',
#   'not',
#   'giving',
#   'me',
#   'the',
#   'option',
#   'but',
#   'we',
#   'want',
#   'seat',
#   'for',
#   'him'],
#  ['always',
#   'have',
#   'it',
#   'together',
#   'you',
#   're',
#   'welcome',
#   'rt',
#   'you',
#   're',
#   'so',
#   'welcome'],
#  ['home', 'to', 'in', 'back', 'to'],
#  ['don',
#   'understand',
#   'why',
#   'you',
#   'need',
#   'dm',
#   'to',
#   'give',
#   'me',
#   'an',
#   'answer',
#   'on',
#   'if',
#   'you',
#   'have',
#   'damaged',
#   'luggage',
#   'policy'],
#  ['does',
#   'that',
#   'mean',
#   'you',
#   'don',
#   'have',
#   'policy',
#   'for',
#   'destroyed',
#   'luggage'],
#  ['is',
#   'there',
#   'special',
#   'assistance',
#   'if',
#   'travel',
#   'alone',
#   'kids',
#   'and',
#   'infant',
#   'priority',
#   'boarding'],
#  ['thank',
#   'you',
#   'for',
#   'checking',
#   'in',
#   'tickets',
#   'are',
#   'purchased',
#   'and',
#   'customer',
#   'is',
#   'happy'],
#  ['is', 'your', 'website', 'ever', 'coming', 'back', 'online'],
#  ['is',
#   'flight',
#   'from',
#   'love',
#   'field',
#   'to',
#   'sfo',
#   'definitely',
#   'cancelled',
#   'flightled',
#   'for',
#   'monday',
#   'february'],
#  ['is', 'flight', 'out', 'of', 'lga', 'to', 'dfw', 'on', 'time'],
#  ['my',
#   'drivers',
#   'license',
#   'is',
#   'expired',
#   'by',
#   'little',
#   'over',
#   'month',
#   'can',
#   'fly',
#   'friday',
#   'morning',
#   'using',
#   'my',
#   'expired',
#   'license'],
#  ['having',
#   'problems',
#   'flight',
#   'booking',
#   'problems',
#   'on',
#   'the',
#   'web',
#   'site',
#   'keeps',
#   'giving',
#   'me',
#   'an',
#   'error',
#   'and',
#   'to',
#   'contact',
#   'by',
#   'phone',
#   'phone',
#   'is',
#   'minute',
#   'wait'],
#  ['how',
#   'do',
#   'reschedule',
#   'my',
#   'cancelled',
#   'flightled',
#   'flights',
#   'online',
#   'the',
#   'change',
#   'button',
#   'is',
#   'greyed',
#   'out'],
#  ['rang',
#   'but',
#   'there',
#   'is',
#   'wait',
#   'for',
#   'minutes',
#   'can',
#   'book',
#   'the',
#   'same',
#   'ticket',
#   'through',
#   'vendor',
#   'fix',
#   'your',
#   'site'],
#  ['got',
#   'flight',
#   'we',
#   'were',
#   'told',
#   'for',
#   'today',
#   'checked',
#   'my',
#   'email',
#   'and',
#   'its',
#   'for',
#   'tomorrow',
#   'this',
#   'is',
#   'unacceptable'],
#  ['our',
#   'flight',
#   'into',
#   'lga',
#   'was',
#   'cancelled',
#   'flighted',
#   'we',
#   're',
#   'stuck',
#   'in',
#   'dallas',
#   'called',
#   'to',
#   'reschedule',
#   'told',
#   'could',
#   'get',
#   'flight',
#   'for',
#   'today'],
#  ['why',
#   'don',
#   'any',
#   'of',
#   'the',
#   'pairings',
#   'include',
#   'red',
#   'wine',
#   'only',
#   'white',
#   'is',
#   'offered'],
#  ['is', 'the', 'website', 'down'],
#  ['your',
#   'site',
#   'seems',
#   'little',
#   'wonked',
#   'right',
#   'now',
#   'may',
#   'want',
#   'to',
#   'have',
#   'look',
#   'tried',
#   'on',
#   'two',
#   'browsers',
#   'no',
#   'css'],
#  ['disappointed',
#   'that',
#   'the',
#   'agent',
#   'at',
#   'the',
#   'designated',
#   'silver',
#   'status',
#   'check',
#   'in',
#   'line',
#   'closed',
#   'to',
#   'assist',
#   'all',
#   'pasengers'],
#  ['plans',
#   'to',
#   'include',
#   'austin',
#   'to',
#   'its',
#   'dallas',
#   'route',
#   'topnews',
#   'arab'],
#  ['is',
#   'it',
#   'normal',
#   'to',
#   'receive',
#   'no',
#   'reply',
#   'from',
#   'central',
#   'baggage'],
#  ['at',
#   'logan',
#   'airport',
#   'and',
#   'waiting',
#   'to',
#   'checkin',
#   'for',
#   'my',
#   'am',
#   'flight',
#   'checkin',
#   'desk',
#   'not',
#   'open',
#   'why'],
#  ['to', 'jump', 'into', 'the', 'dallas', 'austin', 'market'],
#  ['beats',
#   'eps',
#   'views',
#   'takes',
#   'on',
#   'va',
#   'luv',
#   'investor',
#   'business',
#   'daily'],
#  ['lister', 'to', 'my', 'show', 'my', 'on', 'monday'],
#  ['to', 'begin', 'dallas', 'austin', 'in', 'april', 'ketr'],
#  ['congrats',
#   'you',
#   'just',
#   'got',
#   'all',
#   'my',
#   'business',
#   'from',
#   'ewr',
#   'to',
#   'sfo',
#   'lax',
#   'fuck',
#   'you',
#   'fl',
#   'sfo',
#   'ewr',
#   'was',
#   'the',
#   'clincher'],
#  ['applied',
#   'over',
#   'weeks',
#   'ago',
#   'haven',
#   'heard',
#   'back',
#   'and',
#   'flying',
#   'this',
#   'week'],
#  ['love',
#   'to',
#   'know',
#   'what',
#   'your',
#   'policy',
#   'is',
#   'for',
#   'damaged',
#   'luggage'],
#  ['thank', 'you', 'for', 'the', 'follow'],
#  ['too',
#   'many',
#   'apologies',
#   'you',
#   'the',
#   'worse',
#   'airlines',
#   'don',
#   'even',
#   'respond',
#   'to',
#   'your',
#   'cudtomers'],
#  ['shame',
#   'on',
#   'va',
#   'for',
#   'making',
#   'people',
#   'spend',
#   'money',
#   'in',
#   'stranded',
#   'cities',
#   'when',
#   'other',
#   'airlines',
#   'are',
#   'landing',
#   'at',
#   'jfk',
#   'who',
#   'will',
#   'reimburse',
#   'me'],
#  ['dm', 'you'],
#  ['can',
#   'you',
#   'please',
#   'have',
#   'flights',
#   'in',
#   'sjc',
#   'have',
#   'no',
#   'choice',
#   'but',
#   'to',
#   'fly',
#   'southwest',
#   'to',
#   'vegas'],
#  ['too',
#   'bad',
#   'you',
#   'say',
#   'it',
#   'takes',
#   'to',
#   'days',
#   'via',
#   'your',
#   'confirmation',
#   'email',
#   'when',
#   'inquired',
#   'after',
#   'weeks',
#   'you',
#   'claim',
#   'to',
#   'weeks'],
#  ['flight',
#   'from',
#   'bos',
#   'gt',
#   'las',
#   'tomorrow',
#   'was',
#   'cancelled',
#   'flightled',
#   'no',
#   'notification',
#   'wait',
#   'times',
#   'are',
#   'hour',
#   'will',
#   'you',
#   'rebook',
#   'on',
#   'another',
#   'airline'],
#  ['rt',
#   'you',
#   've',
#   'met',
#   'your',
#   'match',
#   'got',
#   'status',
#   'on',
#   'another',
#   'airline',
#   'upgrade',
#   'restr'],
#  ['only', 'way', 'to', 'fly'],
#  ['if', 'only', 'you', 'guys', 'had', 'flights', 'from', 'cmh'],
#  ['lot',
#   'of',
#   'apologies',
#   'being',
#   'thrown',
#   'out',
#   'to',
#   'customers',
#   'from',
#   'what',
#   'can',
#   'see',
#   'very',
#   'sad',
#   'thanks',
#   'for',
#   'nothing',
#   'worst',
#   'airline',
#   'ever'],
#  ['for',
#   'all',
#   'my',
#   'flight',
#   'stuff',
#   'wrong',
#   'and',
#   'did',
#   'nothing',
#   'about',
#   'it',
#   'had',
#   'ever'],
#  ['having',
#   'an',
#   'issue',
#   'finding',
#   'missing',
#   'item',
#   'on',
#   'plane',
#   'can',
#   'you',
#   'help',
#   'me',
#   'find',
#   'which',
#   'airport',
#   'my',
#   'plane',
#   'headed',
#   'to',
#   'next'],
#  ['you', 'will', 'match', 'my', 'status', 'cool'],
#  ['you',
#   've',
#   'met',
#   'your',
#   'match',
#   'got',
#   'status',
#   'on',
#   'another',
#   'airline',
#   'upgrade'],
#  ['trying',
#   'to',
#   'book',
#   'flight',
#   'with',
#   'you',
#   'guys',
#   'and',
#   'your',
#   'website',
#   'won',
#   'let',
#   'me',
#   'about',
#   'to',
#   'lose',
#   'my',
#   'business'],
#  ['you', 'suck'],
#  ['thanks'],
#  ['just', 'dm', 'same', 'issue', 'persisting'],
#  ['because',
#   'we',
#   'never',
#   'rec',
#   'cancelled',
#   'flightlation',
#   'notice',
#   'we',
#   'were',
#   'left',
#   'no',
#   'options',
#   'to',
#   'fly',
#   'out',
#   'of',
#   'ps',
#   'driving',
#   'to',
#   'la',
#   'for',
#   'red',
#   'eye',
#   'mon',
#   'kids'],
#  ['trying', 'to', 'book', 'flight', 'amp', 'your', 'site', 'is', 'down'],
#  ['you',
#   'have',
#   'any',
#   'flights',
#   'flying',
#   'into',
#   'boston',
#   'tomorrow',
#   'need',
#   'to',
#   'be',
#   'home',
#   'and',
#   'you',
#   'cancelled',
#   'flightled',
#   'my',
#   'flight',
#   'and',
#   'didn',
#   'do',
#   'anything'],
#  ['you',
#   'stink',
#   'flight',
#   'cancelled',
#   'flighted',
#   'from',
#   'psp',
#   'to',
#   'jfk',
#   'and',
#   'no',
#   'notification',
#   'or',
#   'ability',
#   'to',
#   'rebook',
#   'better'],
#  ['love',
#   'your',
#   'guy',
#   'song',
#   'we',
#   're',
#   'dancing',
#   'to',
#   'it',
#   'for',
#   'our',
#   'high',
#   'school',
#   'dance',
#   'revue'],
#  ['your', 'website', 'is', 'down', 'and', 'trying', 'to', 'check', 'in'],
#  ['done',
#   'thank',
#   'you',
#   'for',
#   'the',
#   'quick',
#   'response',
#   'apparently',
#   'faster',
#   'than',
#   'sitting',
#   'on',
#   'hold'],
#  ['nervous',
#   'about',
#   'my',
#   'flight',
#   'from',
#   'dc',
#   'to',
#   'lax',
#   'getting',
#   'cancelled',
#   'flightled',
#   'tomorrow',
#   'just',
#   'sent',
#   'you',
#   'dm',
#   'to',
#   'help',
#   'me'],
#  ['cool',
#   'picture',
#   'of',
#   'another',
#   'virginamerica',
#   'plane',
#   'off',
#   'our',
#   'wing',
#   'what',
#   'site'],
#  ['keep', 'up', 'the', 'great', 'work'],
#  ['my',
#   'goodness',
#   'your',
#   'people',
#   'field',
#   'are',
#   'amazing',
#   'under',
#   'pressure',
#   'from',
#   'texas',
#   'in',
#   'crisis',
#   'please',
#   'fly',
#   'me',
#   'to',
#   'ny'],
#  ['thanks',
#   'for',
#   'great',
#   'flight',
#   'from',
#   'la',
#   'to',
#   'boston',
#   'pilots',
#   'did',
#   'great',
#   'job',
#   'landing',
#   'in',
#   'the',
#   'snow',
#   'can',
#   'we',
#   'go',
#   'back',
#   'to',
#   'la',
#   'now'],
#  ['can',
#   'you',
#   'please',
#   'get',
#   'me',
#   'to',
#   'the',
#   'new',
#   'york',
#   'area',
#   'before',
#   'monday',
#   'afternoon'],
#  ['thanks',
#   'so',
#   'much',
#   'for',
#   'the',
#   'awesome',
#   'support',
#   'you',
#   'guys',
#   'rock'],
#  ['seats',
#   'in',
#   'row',
#   'don',
#   'recline',
#   'should',
#   'mention',
#   'that',
#   'on',
#   'your',
#   'website'],
#  ['flight',
#   'delayed',
#   'hours',
#   'in',
#   'la',
#   'due',
#   'to',
#   'mechanical',
#   'problems',
#   'handle',
#   'like',
#   'pros',
#   'but',
#   'you',
#   'could',
#   'have',
#   'tossed',
#   'us',
#   'free',
#   'drink'],
#  ['why',
#   'cancelled',
#   'flight',
#   'flights',
#   'today',
#   'no',
#   'precipitation',
#   'to',
#   'be',
#   'scared',
#   'of'],
#  ['twitter',
#   'team',
#   'you',
#   'guys',
#   'killed',
#   'it',
#   'for',
#   'rescheduling',
#   'me',
#   'asap',
#   'thank',
#   'you'],
#  ['you',
#   'guys',
#   'charged',
#   'me',
#   'to',
#   'reschedule',
#   'flight',
#   'that',
#   'was',
#   'then',
#   'cancelled',
#   'flighted',
#   'and',
#   'are',
#   'now',
#   'refusing',
#   'to',
#   'refund',
#   'it',
#   'what',
#   'the',
#   'deal'],
#  ['can',
#   'access',
#   'your',
#   'website',
#   'from',
#   'safari',
#   'on',
#   'iphone',
#   'seems',
#   'to',
#   'work',
#   'on',
#   'mac',
#   'and',
#   'ipad',
#   'need',
#   'iphone',
#   'to',
#   'add',
#   'passbook'],
#  ['on',
#   'ipad',
#   'and',
#   'iphone',
#   'clicking',
#   'the',
#   'checkin',
#   'link',
#   'in',
#   'the',
#   'email',
#   'received',
#   'at',
#   'hrs',
#   'before',
#   'flight'],
#  ['your',
#   'mobile',
#   'site',
#   'is',
#   'broken',
#   'shows',
#   'header',
#   'elevateuser',
#   'number',
#   'points',
#   'won',
#   'let',
#   'me',
#   'checkin'],
#  ['was',
#   'really',
#   'looking',
#   'forward',
#   'to',
#   'my',
#   'flight',
#   'can',
#   'you',
#   'let',
#   'me',
#   'know',
#   'when',
#   'it',
#   'will',
#   'be',
#   'rescheduled'],
#  ['why',
#   'cancelled',
#   'flight',
#   'flight',
#   'vx',
#   'one',
#   'sec',
#   'its',
#   'delayed',
#   'on',
#   'my',
#   'to',
#   'airport',
#   'the',
#   'next',
#   'its',
#   'cancelled',
#   'flightled',
#   'gonna',
#   'email',
#   'or',
#   'call',
#   'me',
#   'to',
#   'reschedule'],
#  ['did',
#   'it',
#   'but',
#   'there',
#   'was',
#   'problem',
#   'in',
#   'the',
#   'link',
#   'from',
#   'the',
#   'email',
#   'for',
#   'check',
#   'in',
#   'thanks'],
#  ['had',
#   'to',
#   'change',
#   'to',
#   'another',
#   'airline',
#   'to',
#   'get',
#   'to',
#   'dc',
#   'today',
#   'why',
#   'is',
#   'able',
#   'to',
#   'land',
#   'in',
#   'dc',
#   'but',
#   'not',
#   'you',
#   'cost',
#   'me',
#   'ugh'],
#  ['was',
#   'so',
#   'looking',
#   'forward',
#   'to',
#   'my',
#   'first',
#   'flight',
#   'with',
#   'you',
#   'today',
#   'but',
#   'it',
#   'was',
#   'cancelled',
#   'flightled',
#   'along',
#   'with',
#   'the',
#   'subsequent',
#   'one'],
#  ['when',
#   'are',
#   'you',
#   'putting',
#   'some',
#   'great',
#   'deals',
#   'from',
#   'pdx',
#   'to',
#   'las',
#   'or',
#   'from',
#   'las',
#   'to',
#   'pdx',
#   'show',
#   'me',
#   'your',
#   'love'],
#  ['wish',
#   'can',
#   'afford',
#   'to',
#   'fly',
#   'with',
#   'you',
#   'next',
#   'friday',
#   'going',
#   'back',
#   'home',
#   'love',
#   'everything',
#   'about',
#   'your',
#   'airline'],
#  ['how',
#   'are',
#   'you',
#   'gonna',
#   'have',
#   'deal',
#   'from',
#   'dallas',
#   'to',
#   'dc',
#   'but',
#   'no',
#   'deal',
#   'from',
#   'dc',
#   'to',
#   'dallas'],
#  ['it', 'just', 'bug', 'report', 'guys'],
#  ['hold', 'times', 'at', 'call', 'center', 'are', 'bit', 'much'],
#  ['like'],
#  ['site', 'down'],
#  ['you', 'have', 'the', 'best', 'flight', 'attendant', 'ever'],
#  ['awesome', 'rt', 'watch', 'nominated', 'films', 'at', 'feet'],
#  ['thanks', 'so', 'much'],
#  ['trying',
#   'to',
#   'reset',
#   'my',
#   'password',
#   'email',
#   'never',
#   'arrives',
#   'help'],
#  ['the', 'only', 'airline', 'based', 'in', 'silicon', 'valley'],
#  ['very', 'nicely', 'done'],
#  ['looking',
#   'forward',
#   'to',
#   'watching',
#   'the',
#   'oscars',
#   'on',
#   'my',
#   'flight',
#   'home',
#   'tomorrow',
#   'might',
#   'even',
#   'get',
#   'something',
#   'bubbly',
#   'to',
#   'drink'],
#  ['what',
#   'is',
#   'the',
#   'reason',
#   'for',
#   'the',
#   'delay',
#   'of',
#   'the',
#   'departure',
#   'of',
#   'vx',
#   'from',
#   'jfk',
#   'this',
#   'afternoon'],
#  ['is',
#   'todays',
#   'flight',
#   'from',
#   'palm',
#   'springs',
#   'ca',
#   'to',
#   'jfk',
#   'in',
#   'ny',
#   'cancelled',
#   'flightled'],
#  ['hahaha', 'you', 'guys', 'are', 'amazing', 'love', 'you', 'guys'],
#  ['sounds', 'like', 'fun'],
#  ['any', 'updates', 'on', 'flight', 'from', 'jfk', 'gt', 'lax'],
#  ['spruce', 'moose'],
#  ['the',
#   'css',
#   'on',
#   'your',
#   'site',
#   'is',
#   'right',
#   'now',
#   'please',
#   'fix',
#   'site',
#   'unusable'],
#  ['we',
#   're',
#   'on',
#   'flight',
#   'vegas',
#   'to',
#   'boston',
#   'today',
#   'checked',
#   'in',
#   'online',
#   'but',
#   'our',
#   'bag',
#   'count',
#   'didn',
#   'register',
#   'can',
#   'fix',
#   'that',
#   'somehow'],
#  ['classiq', 'luv', 'virgin', 'america', 'greetingz'],
#  ['hi',
#   'trying',
#   'to',
#   'do',
#   'check',
#   'in',
#   'but',
#   'the',
#   'website',
#   'is',
#   'not',
#   'working',
#   'tried',
#   'different',
#   'browsers',
#   'and',
#   'the',
#   'problem',
#   'continues'],
#  ['thanks',
#   'for',
#   'your',
#   'great',
#   'customer',
#   'service',
#   'today',
#   'amp',
#   'for',
#   'helping',
#   'me',
#   'get',
#   'all',
#   'my',
#   'travel',
#   'sorted',
#   'out'],
#  ['thanks', 'guys', 'sweet', 'route', 'over', 'the', 'rockies'],
#  ['love',
#   'the',
#   'music',
#   'blasting',
#   'at',
#   'gate',
#   'in',
#   'while',
#   'waiting',
#   'for',
#   'flight',
#   'to',
#   'only',
#   'if',
#   'could',
#   'get',
#   'an',
#   'iced',
#   'coffee'],
#  ['the',
#   'passenger',
#   'in',
#   'flt',
#   'that',
#   'assaulted',
#   'me',
#   'shouldn',
#   'have',
#   'flown',
#   'trust',
#   'he',
#   'banned',
#   'crew',
#   'filed',
#   'report',
#   'to'],
#  ['current',
#   'bug',
#   'on',
#   'website',
#   'shows',
#   'select',
#   'departure',
#   'city',
#   'when',
#   'selecting',
#   'destination',
#   'city'],
#  ['luggage',
#   'was',
#   'severely',
#   'dented',
#   'missing',
#   'wheel',
#   'coming',
#   'off',
#   'baggage',
#   'claim',
#   'in',
#   'san',
#   'luggage',
#   'agent',
#   'miranda',
#   'think',
#   'wasn',
#   'any',
#   'help'],
#  ['thank',
#   'you',
#   'for',
#   'the',
#   'easy',
#   'itinerary',
#   'shift',
#   'for',
#   'impending',
#   'weather',
#   'quick',
#   'painless',
#   'amp',
#   'free'],
#  ['if',
#   'you',
#   'love',
#   'to',
#   'see',
#   'more',
#   'girls',
#   'be',
#   'inspired',
#   'to',
#   'become',
#   'pilots',
#   'rt',
#   'our',
#   'free',
#   'woaw',
#   'event',
#   'march',
#   'at',
#   'abq'],
#  ['thanks',
#   'good',
#   'times',
#   'there',
#   'and',
#   'back',
#   'the',
#   'entire',
#   'flight'],
#  ['beats',
#   'expectations',
#   'shares',
#   'take',
#   'off',
#   'santa',
#   'cruz',
#   'sentinel'],
#  ['any',
#   'plans',
#   'to',
#   'start',
#   'flying',
#   'direct',
#   'from',
#   'dal',
#   'to',
#   'las'],
#  ['big', 'love', 'gratitude', 'mpower', 'werin', 'vipswagbags'],
#  ['you',
#   're',
#   'doing',
#   'great',
#   'job',
#   'adding',
#   'little',
#   'luxuries',
#   'aesthetics',
#   'that',
#   'improve',
#   'the',
#   'air',
#   'travel',
#   'experience',
#   'thank',
#   'you',
#   'keep',
#   'it',
#   'up'],
#  ['requested',
#   'window',
#   'seat',
#   'and',
#   'confirmed',
#   'window',
#   'but',
#   'got',
#   'stuck',
#   'in',
#   'middle',
#   'seat',
#   'not',
#   'good',
#   'way',
#   'to',
#   'treat',
#   'silver',
#   'member'],
#  ['grand', 'budapest', 'hotel'],
#  ['this', 'is', 'what', 'you', 'missed', 'next', 'trip', 'to', 'the'],
#  ['paid',
#   'for',
#   'direct',
#   'flight',
#   'on',
#   'purpose',
#   'not',
#   'to',
#   'have',
#   'to',
#   'stop',
#   'for',
#   'fuel',
#   'exhausted',
#   'frequent',
#   'flier',
#   'and',
#   'nothing',
#   'for',
#   'inconvenience'],
#  ['there',
#   'is',
#   'something',
#   'wrong',
#   'with',
#   'you',
#   'website',
#   'in',
#   'safari',
#   'iphone'],
#  ['thanks',
#   'for',
#   'gate',
#   'checking',
#   'my',
#   'baggage',
#   'on',
#   'your',
#   'full',
#   'flight',
#   'dfw',
#   'lax',
#   'and',
#   'giving',
#   'me',
#   'early',
#   'boarding',
#   'too'],
#  ['already', 'checked', 'in', 'so', 'the', 'page', 'expired'],
#  ['boo',
#   'for',
#   'not',
#   'refunding',
#   'seat',
#   'upgrade',
#   'fee',
#   'did',
#   'not',
#   'want',
#   'to',
#   'buy',
#   'in',
#   'the',
#   'first',
#   'place'],
#  ['shares', 'rise', 'on', 'financial', 'results', 'usa', 'today'],
#  ['adds',
#   'pillows',
#   'instead',
#   'of',
#   'lie',
#   'flat',
#   'seats',
#   'in',
#   'first',
#   'class',
#   'arms',
#   'race'],
#  ['see', 'what', 'you', 'did', 'there'],
#  ['way', 'to', 'take', 'advantage', 'of'],
#  ['you', 'know', 'flying', 'virgin', 'for', 'the', 'fight'],
#  ['your', 'inflight', 'team', 'makes', 'the', 'experience'],
#  ['cutest',
#   'salt',
#   'and',
#   'pepper',
#   'shaker',
#   'ever',
#   'just',
#   'when',
#   'think',
#   'you',
#   'guys',
#   'can',
#   'get',
#   'any',
#   'better',
#   'you',
#   'just',
#   'do'],
#  ['moved',
#   'my',
#   'seat',
#   'with',
#   'no',
#   'notice',
#   'better',
#   'seat',
#   'is',
#   'cabin',
#   'select',
#   'not',
#   'behind',
#   'the',
#   'row',
#   'selected'],
#  ['shares', 'up', 'on', 'results'],
#  ['fav', 'airline'],
#  ['we', 'have', 'hot', 'female', 'pilot', 'sweet', 'dca', 'to', 'sfo'],
#  ['when',
#   'are',
#   'you',
#   'guys',
#   'going',
#   'to',
#   'start',
#   'flying',
#   'to',
#   'paris',
#   'you',
#   're',
#   'welcome'],
#  ['what',
#   'is',
#   'your',
#   'policy',
#   'on',
#   'flying',
#   'after',
#   'surgery',
#   'am',
#   'still',
#   'waiting',
#   'for',
#   'answer',
#   'so',
#   'can',
#   'tell',
#   'me',
#   'doctor'],
#  ['already',
#   'contacted',
#   'central',
#   'baggage',
#   'amp',
#   'sent',
#   'dm',
#   'is',
#   'charging',
#   'me',
#   'for',
#   'the',
#   'dress',
#   'that',
#   'was',
#   'in',
#   'the',
#   'lost',
#   'suitcase'],
#  ['thank', 'you'],
#  ['is',
#   'there',
#   'anything',
#   'going',
#   'on',
#   'with',
#   'the',
#   'website',
#   've',
#   'been',
#   'getting',
#   'lot',
#   'of',
#   'errors',
#   'past',
#   'minutes'],
#  ['think',
#   'left',
#   'something',
#   'on',
#   'the',
#   'plane',
#   'yesterday',
#   'who',
#   'do',
#   'call',
#   'ah'],
#  ['need', 'you', 'to', 'follow', 'back', 'in', 'order', 'to', 'dm'],
#  ['need', 'to', 'start', 'flying', 'to'],
#  ['they',
#   'told',
#   'to',
#   'check',
#   'with',
#   'the',
#   'airline',
#   'regulation',
#   'first',
#   'so',
#   'that',
#   'is',
#   'why',
#   'contacted',
#   'you'],
#  ['have',
#   'just',
#   'checked',
#   'in',
#   'flight',
#   'to',
#   'sfo',
#   'from',
#   'lax',
#   'amp',
#   'been',
#   'told',
#   'as',
#   'atlantic',
#   'flying',
#   'club',
#   'gold',
#   'get',
#   'no',
#   'benefits'],
#  ['husband',
#   'and',
#   'ordered',
#   'three',
#   'drinks',
#   'via',
#   'my',
#   'screen',
#   'and',
#   'they',
#   'never',
#   'came',
#   'awesome'],
#  ['soooo',
#   'are',
#   'you',
#   'guys',
#   'going',
#   'to',
#   'leave',
#   'the',
#   'seatbelt',
#   'light',
#   'on',
#   'all',
#   'flight',
#   'you',
#   'can',
#   'barely',
#   'call',
#   'this',
#   'turbulence'],
#  ['what', 'is', 'your', 'policy', 'on', 'flying', 'after', 'surgery'],
#  ['posts', 'second', 'consecutive', 'full', 'year', 'net', 'profit'],
#  ['funny',
#   'story',
#   'your',
#   'website',
#   'is',
#   'broken',
#   'you',
#   'have',
#   'missing',
#   'javascript',
#   'and',
#   'stylesheets',
#   'on',
#   'the',
#   'checkin',
#   'process',
#   'dislike',
#   'this'],
#  ['would',
#   'love',
#   'to',
#   'do',
#   'more',
#   'for',
#   'virgin',
#   'just',
#   'like',
#   'do',
#   'for'],
#  ['results', 'handily', 'exceed', 'forecasts'],
#  ['applied',
#   'for',
#   'position',
#   'in',
#   'and',
#   'was',
#   'wondering',
#   'if',
#   'you',
#   'guys',
#   'received',
#   'my',
#   'application'],
#  ['achieves',
#   'second',
#   'year',
#   'of',
#   'profitability',
#   'despite',
#   'revenue',
#   'pressure'],
#  ['gives', 'positive', 'outlook', 'but', 'sees', 'increased', 'competition'],
#  ['trying',
#   'to',
#   'check',
#   'into',
#   'my',
#   'am',
#   'ct',
#   'flight',
#   'tmm',
#   'on',
#   'the',
#   'desktop',
#   'website',
#   'and',
#   'it',
#   'not',
#   'working',
#   'some',
#   'sort',
#   'of',
#   'caching',
#   'bug',
#   'sos'],
#  ['weather', 'delays', 'gt', 'next', 'few', 'weeks'],
#  ['check', 'the', 'website', 'before', 'you', 'go', 'to', 'the', 'airport'],
#  ['do',
#   'you',
#   'guys',
#   'know',
#   'your',
#   'check',
#   'in',
#   'links',
#   'from',
#   'emails',
#   'are',
#   'broken'],
#  ['pilot',
#   'says',
#   'we',
#   'expect',
#   'choppy',
#   'landing',
#   'in',
#   'nyc',
#   'due',
#   'to',
#   'some',
#   'gusty',
#   'winds',
#   'temperature',
#   'of',
#   'about',
#   'degrees',
#   'amp',
#   'the',
#   'windchill'],
#  ['loved',
#   'it',
#   'can',
#   'wait',
#   'for',
#   'monday',
#   'return',
#   'flight',
#   'mostly',
#   'just',
#   'to',
#   'watch',
#   'the',
#   'inflight',
#   'safety',
#   'video',
#   'again'],
#  ['lost',
#   'my',
#   'luggage',
#   'days',
#   'ago',
#   'on',
#   'flight',
#   'vx',
#   'from',
#   'lax',
#   'to',
#   'iad',
#   'amp',
#   'calling',
#   'every',
#   'day',
#   'no',
#   'response',
#   'please',
#   'give',
#   'me',
#   'back',
#   'my',
#   'stuff'],
#  ['the',
#   'flight',
#   'booking',
#   'problems',
#   'section',
#   'of',
#   'your',
#   'website',
#   'seems',
#   'to',
#   'be',
#   'broken',
#   'on',
#   'chrome',
#   'might',
#   'wanna',
#   'look',
#   'into',
#   'that'],
#  ['hi',
#   'just',
#   'wanted',
#   'to',
#   'see',
#   'if',
#   'you',
#   'have',
#   'any',
#   'new',
#   'routes',
#   'planned',
#   'this',
#   'year',
#   'for',
#   'newark',
#   'love',
#   'flying',
#   'you',
#   'guys',
#   'and',
#   'hope',
#   'to',
#   'do',
#   'so',
#   'more'],
#  ['mean',
#   'probably',
#   'inappropriate',
#   'while',
#   'on',
#   'board',
#   'but',
#   'it',
#   'on'],
#  ['happy', 'to', 'spend', 'the', 'day', 'together', 'let', 'do', 'this'],
#  ['is', 'saving', 'my', 'sanity', 'right', 'now'],
#  ['missed', 'my', 'flight', 'how', 'does', 'standby', 'work'],
#  ['they',
#   'were',
#   'very',
#   'understanding',
#   'and',
#   'helped',
#   'me',
#   'out',
#   'thx'],
#  ['brought',
#   'it',
#   'all',
#   'the',
#   'way',
#   'across',
#   'the',
#   'country',
#   'today',
#   'see'],
#  ['thank', 'you', 'absolutely', 'will'],
#  ['looks', 'like', 'broken', 'link', 'for', 'your', 'assets'],
#  ['are',
#   'you',
#   'ready',
#   'let',
#   'say',
#   'it',
#   'together',
#   'noooo',
#   'turbulence',
#   'today'],
#  ['the',
#   'manage',
#   'itinerary',
#   'section',
#   'of',
#   'your',
#   'website',
#   'seems',
#   'to',
#   'be',
#   'broken',
#   'for',
#   'me'],
#  ['can',
#   'check',
#   'in',
#   'your',
#   'site',
#   'looks',
#   'like',
#   'this',
#   'every',
#   'time',
#   'it',
#   'loads'],
#  ['can',
#   'help',
#   'this',
#   'needs',
#   'urgent',
#   'treatment',
#   'in',
#   'old',
#   'battling',
#   'cancer',
#   'could',
#   'help',
#   'with',
#   'flights'],
#  ['may', 'start', 'service', 'to', 'hawaii', 'from', 'this', 'year'],
#  ['other',
#   'carriers',
#   'are',
#   'less',
#   'than',
#   'half',
#   'price',
#   'for',
#   'round',
#   'trip',
#   'fare',
#   'am',
#   'stunned'],
#  ['wtf',
#   'is',
#   'happening',
#   'in',
#   'pdx',
#   'late',
#   'flight',
#   'march',
#   'such',
#   'that',
#   'one',
#   'way',
#   'from',
#   'sfo',
#   'is'],
#  ['add', 'dtw', 'and', 'sold'],
#  ['how',
#   'about',
#   'some',
#   'free',
#   'drinks',
#   'on',
#   'the',
#   'flight',
#   'back',
#   'for',
#   'the',
#   'free',
#   'promo'],
#  ['thanks'],
#  ['momma', 'made', 'it'],
#  ['please',
#   'contact',
#   'me',
#   'about',
#   'portfolio',
#   'left',
#   'on',
#   'flight',
#   'vx',
#   'from',
#   'jfk',
#   'to',
#   'sfo',
#   'tonite',
#   'seat',
#   'am',
#   'need',
#   'it',
#   'returned',
#   'call'],
#  ['help',
#   'was',
#   'on',
#   'flight',
#   'from',
#   'jkf',
#   'tonight',
#   'seat',
#   'left',
#   'portfolio',
#   'need',
#   'it',
#   'back'],
#  ['seattle',
#   'bound',
#   'wifey',
#   'got',
#   'me',
#   'the',
#   'duffle',
#   'for',
#   'vday',
#   'she',
#   'keeper',
#   'holla'],
#  ['my',
#   'luggage',
#   'is',
#   'gone',
#   've',
#   'filed',
#   'my',
#   'paperwork',
#   'promised',
#   'call',
#   'email',
#   'still',
#   'no',
#   'resolution',
#   'or',
#   'response',
#   'from',
#   'central',
#   'luggage'],
#  ['debbie',
#   'baldwin',
#   'gave',
#   'performance',
#   'of',
#   'the',
#   'safety',
#   'demo',
#   'this',
#   'evening',
#   'on',
#   'vx'],
#  ['thanks'],
#  ['thanks', 'for', 'taking', 'care', 'of', 'on', 'her', 'flight'],
#  ['thanks', 'for', 'the', 'lovely', 'soft', 'views', 'to'],
#  ['requested',
#   'mileage',
#   'challenge',
#   'for',
#   'status',
#   'several',
#   'weeks',
#   'ago',
#   'online',
#   'but',
#   'haven',
#   'heard',
#   'back',
#   'how',
#   'do',
#   'get',
#   'help',
#   'with',
#   'this'],
#  ['just',
#   'trying',
#   'to',
#   'book',
#   'tickets',
#   'to',
#   'nyc',
#   'and',
#   'facing',
#   'super',
#   'fun',
#   'broken',
#   'styling',
#   'don',
#   'worry',
#   'll',
#   'keep',
#   'trying'],
#  ['many', 'thanks', 'for', 'the', 'follow', 'looking', 'for', 'any', 'help'],
#  ['nice', 'lofty', 'view'],
#  ['applied',
#   'for',
#   'status',
#   'match',
#   'on',
#   'feb',
#   'got',
#   'confirmation',
#   'email',
#   'same',
#   'day',
#   'still',
#   'no',
#   'news',
#   'though',
#   'you',
#   'guys',
#   'have',
#   'dropped',
#   'ball',
#   'late',
#   'flightly'],
#  ['is', 'my', 'new', 'go', 'to', 'airline'],
#  ['can', 'you', 'help', 'in', 'need', 'of', 'some', 'help', 'in'],
#  ['adore',
#   'you',
#   'and',
#   'am',
#   'so',
#   'looking',
#   'forward',
#   'to',
#   'my',
#   'flight',
#   'to',
#   'austin',
#   'in',
#   'two',
#   'weeks'],
#  ['was',
#   'so',
#   'glad',
#   'it',
#   'was',
#   'mentioned',
#   'took',
#   'my',
#   'first',
#   'virgin',
#   'flight',
#   'few',
#   'years',
#   'back',
#   'and',
#   'it',
#   'was',
#   'transformative',
#   'experience'],
#  ['flight',
#   'booking',
#   'problems',
#   'flight',
#   'to',
#   'uphold',
#   'my',
#   'status',
#   'match',
#   'do',
#   'taxes',
#   'on',
#   'ticket',
#   'count',
#   'as',
#   'earned',
#   'status',
#   'points'],
#  ['trying',
#   'to',
#   'check',
#   'in',
#   'but',
#   'looks',
#   'like',
#   'your',
#   'site',
#   'is',
#   'down'],
#  ['spending',
#   'my',
#   'birthday',
#   'night',
#   'with',
#   'you',
#   'dal',
#   'dca',
#   'get',
#   'me',
#   'home'],
#  ['sent',
#   'couple',
#   'messages',
#   'to',
#   'the',
#   'email',
#   'you',
#   'provided',
#   'but',
#   'to',
#   'no',
#   'avail',
#   'will',
#   'try',
#   'again',
#   'next',
#   'year',
#   'cheers'],
#  ['first',
#   'time',
#   'flying',
#   'virgin',
#   'went',
#   'to',
#   'thanks',
#   'for',
#   'the',
#   'smooth',
#   'ride',
#   'easily',
#   'my',
#   'new',
#   'fav',
#   'airline'],
#  ['seriously',
#   'though',
#   'will',
#   'there',
#   'not',
#   'be',
#   'direct',
#   'flights',
#   'from',
#   'sfo',
#   'fll',
#   'in',
#   'may'],
#  ['it',
#   'fine',
#   'already',
#   'done',
#   'with',
#   'my',
#   'purchase',
#   'but',
#   'you',
#   'should',
#   'try',
#   'it',
#   'just',
#   'go',
#   'most',
#   'of',
#   'the',
#   'way',
#   'through',
#   'then',
#   'go',
#   'back'],
#  ['not',
#   'really',
#   'the',
#   'experience',
#   'was',
#   'hoping',
#   'ws',
#   'forced',
#   'check',
#   'in',
#   'small',
#   'carry',
#   'on',
#   'nothing',
#   'but',
#   'empty',
#   'cabin',
#   'space',
#   'on',
#   'board'],
#  ['wjere', 'is', 'our', 'luggage', 'slow', 'at', 'lax'],
#  ['to', 'jump', 'into', 'the', 'market'],
#  ['spoke',
#   'with',
#   'representative',
#   'that',
#   'offered',
#   'no',
#   'solution',
#   'am',
#   'loyal',
#   'customer',
#   'who',
#   'flies',
#   'on',
#   'as',
#   'well'],
#  ['am',
#   'deeply',
#   'disappointed',
#   'that',
#   'your',
#   'birthday',
#   'promo',
#   'was',
#   'not',
#   'applied',
#   'to',
#   'trip',
#   'booked',
#   'mere',
#   'days',
#   'before',
#   'received',
#   'the',
#   'email'],
#  ['what',
#   'happened',
#   'to',
#   'direct',
#   'flights',
#   'from',
#   'sfo',
#   'fll',
#   'looking',
#   'in',
#   'may',
#   'only',
#   'see',
#   'connecting'],
#  ['can',
#   'you',
#   'help',
#   'left',
#   'my',
#   'blazer',
#   'in',
#   'kooples',
#   'jacket',
#   'bag',
#   'at',
#   'rd',
#   'row',
#   'second',
#   'seat',
#   'from',
#   'right',
#   'gate',
#   'lax',
#   'flight',
#   'to',
#   'sfo'],
#  ['partners',
#   'with',
#   'checkout',
#   'as',
#   'mobile',
#   'payment',
#   'method',
#   'to',
#   'help',
#   'boost',
#   'mobile',
#   'conversion',
#   'rates'],
#  ['just',
#   'promoting',
#   'the',
#   'product',
#   'is',
#   'all',
#   'had',
#   'problem',
#   'with',
#   'southwest',
#   'and',
#   'recommend',
#   'noneother',
#   'than',
#   'the',
#   'best'],
#  ['love',
#   'you',
#   'guys',
#   'but',
#   'pls',
#   'get',
#   'some',
#   'direct',
#   'routes',
#   'las',
#   'to',
#   'aus'],
#  ['would', 'like', 'help', 'with', 'some', 'flights', 'please'],
#  ['bruh', 'turn', 'down', 'for', 'what'],
#  ['of',
#   'course',
#   'work',
#   'for',
#   'and',
#   'obsessed',
#   'with',
#   'the',
#   'entire',
#   'virgin',
#   'family'],
#  ['ok', 'first', 'time', 'flying', 'with', 'you', 'tonight'],
#  ['digging',
#   'the',
#   'swanky',
#   'pink',
#   'mood',
#   'lighting',
#   'during',
#   'the',
#   'flight',
#   'from',
#   'nyc',
#   'to',
#   'sfo',
#   'just',
#   'needs',
#   'cabaret',
#   'singer',
#   'think',
#   'about',
#   'it'],
#  ['done',
#   'but',
#   'need',
#   'the',
#   'receipt',
#   'asap',
#   'could',
#   'you',
#   'please',
# ...
#   'people',
#   'not',
#   'pretty',
#   'this',
#   'is'],
#  ['landed',
#   'in',
#   'boston',
#   'at',
#   'last',
#   'night',
#   'the',
#   'hours',
#   'of',
#   'traveling',
#   'was',
#   'rough',
#   'tho'],
#  ['fail',
#   'you',
#   'cancelled',
#   'flightled',
#   'our',
#   'flight',
#   'frm',
#   'gjt',
#   'and',
#   'then',
#   'used',
#   'our',
#   'reserv',
#   'home',
#   'to',
#   'iah',
#   'from',
#   'sea',
#   'for',
#   'reflight',
#   'booking',
#   'problems',
#   'out',
#   'our',
#   'permission'],
#  ['just',
#   'sent',
#   'thank',
#   'rt',
#   'please',
#   'dm',
#   'your',
#   'confirmation',
#   'number',
#   'if',
#   'reflight',
#   'booking',
#   'problems',
#   'is',
#   'needed',
#   'thank',
#   'you',
#   'ey'],
#  ['has',
#   'made',
#   'my',
#   'no',
#   'fly',
#   'list',
#   'other',
#   'airlines',
#   'wait',
#   'when',
#   'connector',
#   'late',
#   'flight',
#   'stuck',
#   'in',
#   'iah'],
#  ['so',
#   'what',
#   'the',
#   'deal',
#   'do',
#   'provide',
#   'voucher',
#   'for',
#   'overnight',
#   'or',
#   'am',
#   'cozy',
#   'on',
#   'the',
#   'floor',
#   'at'],
#  ['also',
#   'the',
#   'mere',
#   'fact',
#   'that',
#   'have',
#   'to',
#   'go',
#   'online',
#   'to',
#   'issue',
#   'statement',
#   'vice',
#   'calling',
#   'and',
#   'talking',
#   'to',
#   'some',
#   'directly',
#   'is',
#   'one',
#   'good',
#   'example'],
#  ['thank', 'you', 'flew', 'into', 'newark', 'from', 'vail', 'eagle'],
#  ['have',
#   'weekend',
#   'of',
#   'dealing',
#   'with',
#   'your',
#   'company',
#   'that',
#   'would',
#   'say',
#   'otherwise'],
#  ['now', 'what', 'flight', 'was', 'gone', 'when', 'got', 'off', 'plane'],
#  ['the',
#   'proper',
#   'response',
#   'sorry',
#   'for',
#   'your',
#   'wait',
#   'what',
#   'flight',
#   'were',
#   'you',
#   'on',
#   'so',
#   'we',
#   'can',
#   'look',
#   'into',
#   'the',
#   'issue',
#   'that',
#   'how',
#   'would',
#   'handle'],
#  ['your',
#   'customer',
#   'service',
#   'is',
#   'terrible',
#   'stood',
#   'inline',
#   'hours',
#   'no',
#   'flights',
#   'and',
#   'hours',
#   'late',
#   'flightr',
#   'still',
#   'no',
#   'bag'],
#  ['please',
#   'upload',
#   'the',
#   'march',
#   'on',
#   'demand',
#   'entertainment',
#   'listing',
#   'on',
#   'your',
#   'website'],
#  ['so', 'you', 'are', 'inadequate', 'by', 'accident'],
#  ['denver', 'international', 'airport'],
#  ['thank',
#   'you',
#   'for',
#   'responding',
#   'so',
#   'quickly',
#   'with',
#   'helpful',
#   'tool'],
#  ['boarding',
#   'time',
#   'shows',
#   'min',
#   'and',
#   'your',
#   'gate',
#   'agent',
#   'started',
#   'at',
#   'showed',
#   'up',
#   'at',
#   'and',
#   'they',
#   'had',
#   'to',
#   'check',
#   'bag'],
#  ['agent',
#   'in',
#   'las',
#   'letting',
#   'customers',
#   'know',
#   'they',
#   'can',
#   'help',
#   'them',
#   'rebook',
#   'delayed',
#   'flight',
#   'to',
#   'den'],
#  ['empathizes',
#   'my',
#   'disappointment',
#   'that',
#   'stclass',
#   'flight',
#   'nonworking',
#   'entertainmnt',
#   'is',
#   'worth'],
#  ['and', 'when', 'that', 'doesn', 'work'],
#  ['did',
#   'you',
#   'have',
#   'seen',
#   'my',
#   'message',
#   'today',
#   'about',
#   'mcdonnell',
#   'douglas',
#   'dc',
#   'model',
#   'will',
#   'hear',
#   'it',
#   'if',
#   'you',
#   'read',
#   'it',
#   'goodnight',
#   'now'],
#  ['searched',
#   'for',
#   'mileage',
#   'tickets',
#   'to',
#   'bom',
#   'couldn',
#   'find',
#   'single',
#   'one',
#   'is',
#   'saver',
#   'awards',
#   'see',
#   'how',
#   'you',
#   'play',
#   'earn',
#   'miles',
#   'but',
#   'can',
#   'use',
#   'them'],
#  ['flight',
#   'arrives',
#   'minutes',
#   'early',
#   'but',
#   'then',
#   'have',
#   'we',
#   'to',
#   'wait',
#   'for',
#   'an',
#   'hour',
#   'for',
#   'our',
#   'bags'],
#  ['that',
#   'not',
#   'the',
#   'issue',
#   'the',
#   'fact',
#   'that',
#   'no',
#   'one',
#   'even',
#   'called',
#   'despite',
#   'promises',
#   'to',
#   'confirm',
#   'the',
#   'bag',
#   'location',
#   'is'],
#  ['what',
#   'girl',
#   'gotta',
#   'do',
#   'to',
#   'get',
#   'flight',
#   'name',
#   'change',
#   'when',
#   'she',
#   'bought',
#   'one',
#   'for',
#   'mean',
#   'ex',
#   'boyfriend',
#   'and',
#   'needs',
#   'girl',
#   'trip',
#   'stat'],
#  ['thank',
#   'you',
#   'we',
#   'are',
#   'signed',
#   'up',
#   'for',
#   'notifications',
#   'we',
#   'shall',
#   'watch',
#   'and',
#   'wait'],
#  ['still',
#   'waiting',
#   'to',
#   'hear',
#   'back',
#   'my',
#   'wallet',
#   'was',
#   'stolen',
#   'from',
#   'one',
#   'of',
#   'your',
#   'planes',
#   'so',
#   'would',
#   'appreciate',
#   'resolution',
#   'here'],
#  ['would',
#   'love',
#   'if',
#   'someone',
#   'could',
#   'get',
#   'me',
#   'back',
#   'to',
#   'austin',
#   'tonight',
#   'and',
#   'do',
#   'not',
#   'wish',
#   'to',
#   'wait',
#   'til',
#   'tomorrow',
#   'morning'],
#  ['or',
#   'has',
#   'lost',
#   'my',
#   'baggage',
#   'heard',
#   'different',
#   'things',
#   'from',
#   'different',
#   'employees',
#   'of',
#   'has',
#   'said',
#   'nothing'],
#  ['cs',
#   'thinks',
#   'that',
#   'miles',
#   'can',
#   'repair',
#   'the',
#   'damage',
#   'done',
#   'it',
#   'will',
#   'be',
#   'interesting',
#   'if',
#   'they',
#   'travel',
#   'in',
#   'and',
#   'exp',
#   'the',
#   'worst',
#   'flight',
#   'ever'],
#  ['have',
#   'flight',
#   'out',
#   'of',
#   'dfw',
#   'on',
#   'tuesday',
#   'how',
#   'far',
#   'in',
#   'advance',
#   'will',
#   'you',
#   'give',
#   'notice',
#   'if',
#   'cancelled',
#   'flightled'],
#  ['am',
#   'signed',
#   'up',
#   'for',
#   'notifications',
#   'this',
#   'is',
#   'the',
#   'first',
#   'trip',
#   'was',
#   'not',
#   'updated',
#   'on',
#   'not',
#   'sure',
#   'why',
#   'this',
#   'happened'],
#  ['thank',
#   'you',
#   'took',
#   'care',
#   'of',
#   'everything',
#   'and',
#   'made',
#   'it',
#   'right',
#   'that',
#   'the',
#   'experience',
#   'used',
#   'to',
#   'opened',
#   'the',
#   'app',
#   'to',
#   'find',
#   'flight',
#   'changed'],
#  ['that',
#   'is',
#   'not',
#   'in',
#   'line',
#   'with',
#   'your',
#   'responses',
#   'here',
#   'and',
#   'now',
#   'waiting',
#   'until',
#   'tomorrow',
#   'morning',
#   'because',
#   'all',
#   'the',
#   'flights',
#   'are',
#   'overbooked'],
#  ['took',
#   'the',
#   'exact',
#   'same',
#   'aircraft',
#   'in',
#   'to',
#   'lax',
#   'days',
#   'ago',
#   'it',
#   'fit',
#   'no',
#   'problem',
#   'the',
#   'agent',
#   'today',
#   'told',
#   'some',
#   'nonsense',
#   'about',
#   'policy',
#   'change'],
#  ['your',
#   'helpful',
#   'agents',
#   'in',
#   'club',
#   'helped',
#   'am',
#   'just',
#   'out',
#   'baggage',
#   'fees',
#   'and',
#   'night',
#   'of',
#   'my',
#   'life',
#   'stop',
#   'doing',
#   'business',
#   'with'],
#  ['never', 'heard', 'of', 'this'],
#  ['doesn',
#   'charge',
#   'ticket',
#   'change',
#   'fees',
#   'do',
#   'they',
#   'not',
#   'incur',
#   'the',
#   'same',
#   'mysterious',
#   'costs',
#   'that',
#   'you',
#   'incur'],
#  ['exhausted',
#   'amp',
#   'frustrated',
#   'link',
#   'to',
#   'fb',
#   'post',
#   'abt',
#   'my',
#   'travel',
#   'issue'],
#  ['was',
#   'denied',
#   'getting',
#   'on',
#   'the',
#   'plane',
#   'getting',
#   'the',
#   'chance',
#   'to',
#   'prove',
#   'it',
#   'fits',
#   'not',
#   'rookie',
#   'read',
#   'my',
#   'bio'],
#  ['that',
#   'exactly',
#   'the',
#   'point',
#   'it',
#   'fits',
#   'premier',
#   'access',
#   'boarding',
#   'group',
#   'this',
#   'was',
#   'return',
#   'ticket',
#   've',
#   'been',
#   'doing',
#   'this',
#   'for',
#   'yrs'],
#  ['ve',
#   'never',
#   'experienced',
#   'worst',
#   'customer',
#   'service',
#   'placing',
#   'blame',
#   'on',
#   'codeshare',
#   'partners',
#   'and',
#   'not',
#   'assuming',
#   'responsibility',
#   'is',
#   'unacceptable'],
#  ['currently',
#   'on',
#   'board',
#   'so',
#   'not',
#   'now',
#   'check',
#   'in',
#   'was',
#   'terrible',
#   'staff',
#   'rude',
#   'expensive',
#   'luggage',
#   'thrown',
#   'around',
#   'etc'],
#  ['fucked',
#   'up',
#   'then',
#   'voided',
#   'my',
#   'ticket',
#   'and',
#   'kept',
#   'my',
#   'money',
#   'not',
#   'even',
#   'an',
#   'apology',
#   'will',
#   'never',
#   'fly',
#   'with',
#   'your',
#   'airline',
#   'again'],
#  ['has',
#   'the',
#   'worst',
#   'customer',
#   'svcs',
#   'this',
#   'kevin',
#   'rep',
#   'at',
#   'call',
#   'center',
#   'must',
#   'be',
#   'investigated',
#   'my',
#   'baggage',
#   'lost',
#   'and',
#   'there',
#   'no',
#   'help',
#   'but',
#   'argument'],
#  ['should',
#   'not',
#   'sell',
#   'tickets',
#   'for',
#   'on',
#   'has',
#   'terrible',
#   'service',
#   'and',
#   'ua',
#   'staff',
#   'cannot',
#   'reach',
#   'silver'],
#  ['just',
#   'got',
#   'demoted',
#   'from',
#   'gold',
#   'cuz',
#   'my',
#   'hubby',
#   'got',
#   'of',
#   'the',
#   'pqd',
#   'tho',
#   'there',
#   'were',
#   'enuf',
#   'spent',
#   'for',
#   'golds',
#   'discrimination',
#   'angry'],
#  ['thank', 'you'],
#  ['when',
#   'will',
#   'direct',
#   'flights',
#   'from',
#   'belfast',
#   'intl',
#   'to',
#   'newark',
#   'resume',
#   'from',
#   'their',
#   'winter',
#   'break',
#   'thanks'],
#  ['my', 'favorite', 'way', 'to', 'travel', 'thank', 'you'],
#  ['yes',
#   'after',
#   'this',
#   'awful',
#   'weather',
#   'it',
#   'appears',
#   'can',
#   'get',
#   'home'],
#  ['yes',
#   'lots',
#   'you',
#   'have',
#   'terrible',
#   'customer',
#   'service',
#   'at',
#   'newark',
#   'and',
#   'despite',
#   'raising',
#   'complaint',
#   'there',
#   'we',
#   'were',
#   'ignored',
#   'hence',
#   'the',
#   'tweet'],
#  ['lovely',
#   'new',
#   'plane',
#   'from',
#   'lga',
#   'to',
#   'ord',
#   'but',
#   'no',
#   'power',
#   'outlets'],
#  ['but',
#   'if',
#   'tweet',
#   'the',
#   'id',
#   'number',
#   'won',
#   'that',
#   'reveal',
#   'my',
#   'home',
#   'address',
#   'to',
#   'anyone',
#   'on',
#   'the',
#   'web'],
#  ['filed',
#   'delayed',
#   'bag',
#   'report',
#   'on',
#   'saturday',
#   'my',
#   'flight',
#   'was',
#   'cancelled',
#   'flightled',
#   'and',
#   'never',
#   'went',
#   'anywhere'],
#  ['the', 'person', 'is', 'currently', 'bettween', 'gates', 'and', 'in', 'lax'],
#  ['need',
#   'it',
#   'there',
#   'before',
#   'she',
#   'lands',
#   'so',
#   'she',
#   'can',
#   'have',
#   'the',
#   'ewr',
#   'baggage',
#   'claim',
#   'file',
#   'to',
#   'have',
#   'it',
#   'sent',
#   'but',
#   'the',
#   'employee',
#   'has',
#   'not',
#   'droppeditoffyet'],
#  ['rarely',
#   'ceases',
#   'to',
#   'amaze',
#   'for',
#   'the',
#   'worse',
#   'hope',
#   'this',
#   'is',
#   'the',
#   'last',
#   'time',
#   'have',
#   'to',
#   'fly',
#   'with',
#   'you'],
#  ['thank',
#   'you',
#   'for',
#   'the',
#   'quick',
#   'response',
#   'but',
#   'cannot',
#   'dm',
#   'you',
#   'until',
#   'you',
#   'follow',
#   'me',
#   'as',
#   'well'],
#  ['icloud', 'it', 'is', 'not', 'there', 'yet', 'please', 'help'],
#  ['need',
#   'the',
#   'phone',
#   'number',
#   'to',
#   'baggage',
#   'claim',
#   'in',
#   'lax',
#   'my',
#   'mom',
#   'left',
#   'her',
#   'phone',
#   'and',
#   'someone',
#   'called',
#   'saying',
#   'they',
#   'would',
#   'put',
#   'it',
#   'there',
#   'but',
#   'on'],
#  ['did', 'no', 'response', 'back'],
#  ['this', 'is', 'atrocious', 'customer', 'service'],
#  ['will',
#   'not',
#   'have',
#   'to',
#   'honor',
#   'absurdly',
#   'low',
#   'mistake',
#   'fares',
#   'vía'],
#  ['delayed',
#   'departure',
#   'to',
#   'check',
#   'bags',
#   'at',
#   'gate',
#   'claiming',
#   'space',
#   'filled',
#   'and',
#   'walk',
#   'on',
#   'to',
#   'open',
#   'spaces',
#   'delay'],
#  ['you',
#   'cancelled',
#   'flighted',
#   'our',
#   'flights',
#   'for',
#   'no',
#   'reason',
#   'amp',
#   'now',
#   'we',
#   'have',
#   'been',
#   'on',
#   'the',
#   'phone',
#   'for',
#   'an',
#   'hour',
#   'on',
#   'our',
#   'vacation',
#   'why'],
#  ['that',
#   'your',
#   'response',
#   'shaking',
#   'my',
#   'head',
#   'back',
#   'and',
#   'forth',
#   'with',
#   'tsk',
#   'you',
#   'can',
#   'do',
#   'better',
#   'from',
#   'customer',
#   'service',
#   'to',
#   'your',
#   'apology'],
#  ['thanks',
#   'it',
#   'miles',
#   'from',
#   'rtb',
#   'to',
#   'europe',
#   'to',
#   'do',
#   'multiple',
#   'destination',
#   'so',
#   'we',
#   'could',
#   'stop',
#   'over',
#   'in',
#   'us',
#   'on',
#   'way',
#   'way',
#   'back',
#   'mileage',
#   'diff'],
#  ['of', 'course', 'did', 'the', 'bag', 'should', 'be', 'here', 'by', 'now'],
#  ['you',
#   'are',
#   'the',
#   'worst',
#   'will',
#   'avoid',
#   'you',
#   'like',
#   'the',
#   'plague'],
#  ['is', 'the', 'worst', 'airline', 'in', 'the', 'world'],
#  ['someone',
#   'needs',
#   'to',
#   'dm',
#   'me',
#   'and',
#   'resolve',
#   'this',
#   'correctly',
#   'extremely',
#   'disappointed',
#   'with',
#   'the',
#   'service',
#   'received',
#   'terrible',
#   'management'],
#  ['premier',
#   'gold',
#   'desk',
#   'changes',
#   'flight',
#   'waives',
#   'fees',
#   'gives',
#   'me',
#   'wrong',
#   'flight',
#   'now',
#   'jana',
#   'acosta',
#   'in',
#   'salt',
#   'lake',
#   'refuses',
#   'the',
#   'same',
#   'service',
#   'angry'],
#  ['will',
#   'give',
#   'you',
#   'one',
#   'thing',
#   'you',
#   'are',
#   'consistent',
#   'but',
#   'unfortunately',
#   'you',
#   'are',
#   'consistent',
#   'at',
#   'not',
#   'doing',
#   'your',
#   'job',
#   'well'],
#  ['will', 'but', 'right', 'now', 'to', 'angry'],
#  ['first',
#   'time',
#   'flying',
#   'with',
#   'united',
#   'also',
#   'last',
#   'time',
#   'back',
#   'to',
#   'for',
#   'me'],
#  ['used',
#   'to',
#   'be',
#   'committed',
#   'flyer',
#   'until',
#   'merger',
#   'remember',
#   'now',
#   'why',
#   'switched',
#   'to'],
#  ['the',
#   'least',
#   'you',
#   'could',
#   'do',
#   'is',
#   'offer',
#   'me',
#   'ticket',
#   'in',
#   'coach',
#   'instead',
#   'of',
#   'just',
#   'cancelled',
#   'flighting',
#   'my',
#   'reservation',
#   'because',
#   'of',
#   'your',
#   'glitch'],
#  ['saying',
#   'made',
#   'the',
#   'flight',
#   'but',
#   'with',
#   'poor',
#   'non',
#   'communication',
#   'unaccounted',
#   'for',
#   'lost',
#   'time',
#   'amp',
#   'lots',
#   'of',
#   'frustrated',
#   'flyers',
#   'standing',
#   'around'],
#  ['think', 'dm', 'would', 'be', 'better'],
#  ['gate',
#   'announcement',
#   'states',
#   'delay',
#   'due',
#   'to',
#   'maintenance',
#   'yet',
#   'app',
#   'says',
#   'late',
#   'flight',
#   'arriving',
#   'aircraft',
#   'tell',
#   'the',
#   'truth'],
#  ['you',
#   'are',
#   'easily',
#   'the',
#   'worst',
#   'company',
#   'have',
#   'ever',
#   'experienced',
#   'you',
#   'have',
#   'lost',
#   'someone',
#   'personal',
#   'possessions',
#   'amp',
#   'you',
#   'couldn',
#   'care',
#   'less'],
#  ['how',
#   'can',
#   'your',
#   'app',
#   'show',
#   'arriving',
#   'aircraft',
#   'is',
#   'early',
#   'but',
#   'departing',
#   'flight',
#   'is',
#   'delayed',
#   'due',
#   'to',
#   'late',
#   'flight',
#   'arriving',
#   'aircraft'],
#  ['already',
#   'did',
#   'that',
#   'at',
#   'the',
#   'airport',
#   'and',
#   'hrs',
#   'late',
#   'flightr',
#   'its',
#   'still',
#   'not',
#   'here',
#   'you',
#   'guys',
#   'are',
#   'really',
#   'killing',
#   'me',
#   'today',
#   'trying',
#   'to',
#   'stay',
#   'positive'],
#  ['once',
#   'united',
#   'service',
#   'levels',
#   'reaches',
#   'those',
#   'of',
#   'etihad',
#   'or',
#   'lets',
#   'be',
#   'more',
#   'realistically',
#   'lufthansa',
#   'then',
#   'ill',
#   'consider',
#   'it',
#   'again'],
#  ['really',
#   'someone',
#   'called',
#   'in',
#   'sick',
#   'and',
#   'then',
#   'someone',
#   'forgot',
#   'to',
#   'call',
#   'replacement',
#   'now',
#   'an',
#   'hour',
#   'late',
#   'flight',
#   'to',
#   'take',
#   'off'],
#  ['asked',
#   'flight',
#   'attendant',
#   'what',
#   'typical',
#   'compensation',
#   'would',
#   'be',
#   'amp',
#   'says',
#   'we',
#   'might',
#   'get',
#   'free',
#   'tv'],
#  ['done'],
#  ['thank',
#   'you',
#   'jh',
#   'appreciate',
#   'the',
#   'prompt',
#   'responses',
#   'me',
#   'and',
#   'other',
#   'passengers',
#   'will',
#   'be',
#   'doing',
#   'so'],
#  ['has',
#   'been',
#   'such',
#   'disappointment',
#   'today',
#   'simply',
#   'put',
#   'rather',
#   'unpleased',
#   'with',
#   'things',
#   'currently',
#   'flight',
#   'delayed',
#   'cant',
#   'wait',
#   'to',
#   'just',
#   'get',
#   'home'],
#  ['during',
#   'the',
#   'same',
#   'round',
#   'trip',
#   'my',
#   'non',
#   'english',
#   'speaking',
#   'friend',
#   'was',
#   'stranded',
#   'twice',
#   'for',
#   'hours',
#   'each',
#   'time',
#   'most',
#   'staff',
#   'members',
#   'were',
#   'rude'],
#  ['found',
#   'group',
#   'of',
#   'people',
#   'who',
#   'actually',
#   'hates',
#   'people',
#   'more',
#   'than',
#   'isis',
#   'thats',
#   'right',
#   'united',
#   'airlines'],
#  ['nope',
#   'walked',
#   'up',
#   'amp',
#   'down',
#   'the',
#   'orf',
#   'terminal',
#   'amp',
#   'not',
#   'united',
#   'agent',
#   'to',
#   'be',
#   'found',
#   'showed',
#   'up',
#   'last',
#   'minute',
#   'to',
#   'board',
#   'us',
#   'many',
#   'panicked',
#   'people'],
#  ['thank', 'you'],
#  ['by',
#   'the',
#   'time',
#   'finally',
#   'get',
#   'to',
#   'dallas',
#   'could',
#   'have',
#   'driven',
#   'with',
#   'less',
#   'frustration',
#   'and',
#   'cheaper'],
#  ['trying',
#   'to',
#   'get',
#   'to',
#   'my',
#   'final',
#   'destination',
#   'we',
#   'need',
#   'compensation',
#   'just',
#   'about',
#   'hrs',
#   'of',
#   'personal',
#   'time',
#   'wasted'],
#  ['that',
#   'guy',
#   'really',
#   'has',
#   'no',
#   'customer',
#   'service',
#   'clue',
#   'could',
#   'have',
#   'spent',
#   'effort',
#   'clearing',
#   'bins',
#   'for',
#   'rollerboards',
#   'instead',
#   'of',
#   'art',
#   'projects',
#   'in',
#   'mine'],
#  ['he', 'has', 'no', 'priority', 'and', 'iove', 'it'],
#  ['pleased', 'to', 'be', 'premier', 'platinum'],
#  ...]

# %%
model = gensim.models.Word2Vec(size=150, window=10, min_count=2, sg=1, workers=10)

model.build_vocab(documents)

# %%
model.train(sentences=documents,total_examples=len(documents),epochs=model.iter)
# Out:
# /home/matheus/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   """Entry point for launching an IPython kernel.
# (824822, 1102005)

# %%
model.wv.vocab
# Out:
# {'what': <gensim.models.keyedvectors.Vocab at 0x7fe97d783490>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7fe97d7838d0>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x7fe97d783b90>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7fe97d783b50>,
#  've': <gensim.models.keyedvectors.Vocab at 0x7fe97d76a6d0>,
#  'added': <gensim.models.keyedvectors.Vocab at 0x7fe97d76a590>,
#  'commercials': <gensim.models.keyedvectors.Vocab at 0x7fe97e91bd50>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7fe97e91bad0>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7fe9ae4d3150>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7fe97d76a7d0>,
#  'didn': <gensim.models.keyedvectors.Vocab at 0x7fe97e91bed0>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7fe97d7741d0>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7fe97d774350>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7fe97d774490>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7fe97d7744d0>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7fe97d774550>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7fe97d774590>,
#  'trip': <gensim.models.keyedvectors.Vocab at 0x7fe97d774450>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7fe97d774610>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7fe97d774510>,
#  'aggressive': <gensim.models.keyedvectors.Vocab at 0x7fe97d7742d0>,
#  'blast': <gensim.models.keyedvectors.Vocab at 0x7fe97d7745d0>,
#  'obnoxious': <gensim.models.keyedvectors.Vocab at 0x7fe97d7743d0>,
#  'entertainment': <gensim.models.keyedvectors.Vocab at 0x7fe97d774390>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7fe97d774310>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x7fe97d774210>,
#  'guests': <gensim.models.keyedvectors.Vocab at 0x7fe97d774150>,
#  'faces': <gensim.models.keyedvectors.Vocab at 0x7fe97d774090>,
#  'amp': <gensim.models.keyedvectors.Vocab at 0x7fe97d774690>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7fe97d774250>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7fe97d774710>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7fe97d774190>,
#  'recourse': <gensim.models.keyedvectors.Vocab at 0x7fe97d774790>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7fe97d7746d0>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x7fe97d774810>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7fe97d774750>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7fe97d774890>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7fe97d7748d0>,
#  'seriously': <gensim.models.keyedvectors.Vocab at 0x7fe97d774ed0>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7fe97d774950>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7fe97d7749d0>,
#  'flight': <gensim.models.keyedvectors.Vocab at 0x7fe97d774a10>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7fe97d774a90>,
#  'seats': <gensim.models.keyedvectors.Vocab at 0x7fe97d774ad0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7fe97d774b50>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7fe97d774b90>,
#  'playing': <gensim.models.keyedvectors.Vocab at 0x7fe97d774c10>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7fe97d774c50>,
#  'flying': <gensim.models.keyedvectors.Vocab at 0x7fe97d774cd0>,
#  'va': <gensim.models.keyedvectors.Vocab at 0x7fe97d774d10>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x7fe97d774d90>,
#  'nearly': <gensim.models.keyedvectors.Vocab at 0x7fe97d774dd0>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x7fe97d774e50>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7fe97d774e90>,
#  'fly': <gensim.models.keyedvectors.Vocab at 0x7fe97d774f10>,
#  'vx': <gensim.models.keyedvectors.Vocab at 0x7fe97d774f50>,
#  'ear': <gensim.models.keyedvectors.Vocab at 0x7fe97d774fd0>,
#  'won': <gensim.models.keyedvectors.Vocab at 0x7fe97d774c90>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7fe97d774e10>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x7fe97d774850>,
#  'missed': <gensim.models.keyedvectors.Vocab at 0x7fe97d774d50>,
#  'prime': <gensim.models.keyedvectors.Vocab at 0x7fe97d774f90>,
#  'opportunity': <gensim.models.keyedvectors.Vocab at 0x7fe97d774910>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x7fe97d7747d0>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7fe97d774a50>,
#  'hats': <gensim.models.keyedvectors.Vocab at 0x7fe97d774bd0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7fe97e90a990>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf0710>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf0890>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf0690>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf0850>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf07d0>,
#  'amazing': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf0750>,
#  'arrived': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf0390>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf03d0>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf0410>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf0490>,
#  're': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf0910>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf08d0>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf0590>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7fe97eaf04d0>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x7fe97d7ddf50>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7fe97d782310>,
#  'suicide': <gensim.models.keyedvectors.Vocab at 0x7fe97d7820d0>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7fe97d782190>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7fe97d782250>,
#  'leading': <gensim.models.keyedvectors.Vocab at 0x7fe97d782890>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x7fe97d782290>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7fe97d782210>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x7fe97d782350>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7fe97d7823d0>,
#  'teens': <gensim.models.keyedvectors.Vocab at 0x7fe97d782410>,
#  'lt': <gensim.models.keyedvectors.Vocab at 0x7fe97d782490>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x7fe97d7824d0>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7fe97d782550>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7fe97d782590>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7fe97d782610>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7fe97d782650>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x7fe97d7826d0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7fe97d782710>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7fe97d782790>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x7fe97d7827d0>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x7fe97d782690>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7fe97d782850>,
#  'nd': <gensim.models.keyedvectors.Vocab at 0x7fe97d782750>,
#  'haven': <gensim.models.keyedvectors.Vocab at 0x7fe97d782510>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7fe97d782810>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x7fe97d782390>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7fe97d7825d0>,
#  'st': <gensim.models.keyedvectors.Vocab at 0x7fe97d7822d0>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7fe97d782450>,
#  'skies': <gensim.models.keyedvectors.Vocab at 0x7fe97d782090>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x7fe97d782150>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7fe97d7821d0>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7fe97d782110>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7fe97d782910>,
#  'thanks': <gensim.models.keyedvectors.Vocab at 0x7fe97d782050>,
#  'sfo': <gensim.models.keyedvectors.Vocab at 0x7fe97d782990>,
#  'pdx': <gensim.models.keyedvectors.Vocab at 0x7fe97d7828d0>,
#  'schedule': <gensim.models.keyedvectors.Vocab at 0x7fe97d782a10>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7fe97d782950>,
#  'mia': <gensim.models.keyedvectors.Vocab at 0x7fe97d782a90>,
#  'excited': <gensim.models.keyedvectors.Vocab at 0x7fe97d7829d0>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7fe97d782b10>,
#  'cross': <gensim.models.keyedvectors.Vocab at 0x7fe97d782a50>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x7fe97d782b90>,
#  'lax': <gensim.models.keyedvectors.Vocab at 0x7fe97d782bd0>,
#  'mco': <gensim.models.keyedvectors.Vocab at 0x7fe97d782c50>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x7fe97d782d10>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x7fe97d782dd0>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7fe97d782e90>,
#  'virgin': <gensim.models.keyedvectors.Vocab at 0x7fe97d782f50>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x7fe97d782c90>,
#  'flew': <gensim.models.keyedvectors.Vocab at 0x7fe97d782c10>,
#  'nyc': <gensim.models.keyedvectors.Vocab at 0x7fe97d782cd0>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7fe97d782d50>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7fe97d782f90>,
#  'couldn': <gensim.models.keyedvectors.Vocab at 0x7fe97d782fd0>,
#  'fully': <gensim.models.keyedvectors.Vocab at 0x7fe97d782b50>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x7fe97d782f10>,
#  'seat': <gensim.models.keyedvectors.Vocab at 0x7fe97d782e10>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x7fe97d782ad0>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7fe97d782ed0>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7fe97d782d90>,
#  'gentleman': <gensim.models.keyedvectors.Vocab at 0x7fe97e9261d0>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7fe97e9260d0>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x7fe97e926210>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7fe97e9263d0>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7fe97e9264d0>,
#  'amazingly': <gensim.models.keyedvectors.Vocab at 0x7fe97e926410>,
#  'awesome': <gensim.models.keyedvectors.Vocab at 0x7fe97e926050>,
#  'bos': <gensim.models.keyedvectors.Vocab at 0x7fe97e926510>,
#  'fll': <gensim.models.keyedvectors.Vocab at 0x7fe97e926550>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7fe97e926590>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7fe97e926490>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7fe97e926690>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x7fe97e926450>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7fe97e926610>,
#  'fares': <gensim.models.keyedvectors.Vocab at 0x7fe97e9262d0>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7fe97e926290>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x7fe97e9266d0>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7fe97e926710>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x7fe97e926310>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7fe97e926350>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7fe97e926390>,
#  'carriers': <gensim.models.keyedvectors.Vocab at 0x7fe97e926250>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7fe97d780050>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x7fe97d780110>,
#  'select': <gensim.models.keyedvectors.Vocab at 0x7fe97d7801d0>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7fe97d780290>,
#  'innovation': <gensim.models.keyedvectors.Vocab at 0x7fe97d780350>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7fe97d780410>,
#  'brand': <gensim.models.keyedvectors.Vocab at 0x7fe97d780490>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7fe97d7804d0>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7fe97d780550>,
#  'gt': <gensim.models.keyedvectors.Vocab at 0x7fe97d780590>,
#  'las': <gensim.models.keyedvectors.Vocab at 0x7fe97d780150>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x7fe97d780090>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x7fe97d7800d0>,
#  'permanently': <gensim.models.keyedvectors.Vocab at 0x7fe97d7805d0>,
#  'anytime': <gensim.models.keyedvectors.Vocab at 0x7fe97d7806d0>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x7fe97d780510>,
#  'guys': <gensim.models.keyedvectors.Vocab at 0x7fe97d7803d0>,
#  'messed': <gensim.models.keyedvectors.Vocab at 0x7fe97d780210>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7fe97d780450>,
#  'seating': <gensim.models.keyedvectors.Vocab at 0x7fe97d780790>,
#  'reserved': <gensim.models.keyedvectors.Vocab at 0x7fe97d780850>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7fe97d780910>,
#  'gave': <gensim.models.keyedvectors.Vocab at 0x7fe97d780810>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7fe97d780710>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x7fe97d780690>,
#  'status': <gensim.models.keyedvectors.Vocab at 0x7fe97d7807d0>,
#  'match': <gensim.models.keyedvectors.Vocab at 0x7fe97d7809d0>,
#  'program': <gensim.models.keyedvectors.Vocab at 0x7fe97d780390>,
#  'applied': <gensim.models.keyedvectors.Vocab at 0x7fe97d7802d0>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7fe97d780250>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x7fe97d780a50>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7fe97d780610>,
#  'emailed': <gensim.models.keyedvectors.Vocab at 0x7fe97d780750>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7fe97d780a10>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x7fe97d780ad0>,
#  'happened': <gensim.models.keyedvectors.Vocab at 0x7fe97d780b10>,
#  'ur': <gensim.models.keyedvectors.Vocab at 0x7fe97d780b90>,
#  'vegan': <gensim.models.keyedvectors.Vocab at 0x7fe97d780bd0>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7fe97d780c50>,
#  'options': <gensim.models.keyedvectors.Vocab at 0x7fe97d780c90>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7fe97d780d10>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7fe97d780d50>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7fe97d780dd0>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x7fe97d780e10>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7fe97d780e90>,
#  'eat': <gensim.models.keyedvectors.Vocab at 0x7fe97d780ed0>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7fe97d780f50>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7fe97d780f90>,
#  'hrs': <gensim.models.keyedvectors.Vocab at 0x7fe97d780d90>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x7fe97d780f10>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x7fe97d780cd0>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x7fe97d780fd0>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7fe97d780b50>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x7fe97d780e50>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x7fe97d7808d0>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7fe97d780c10>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7fe97d780950>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7fe97d780a90>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7fe97d780650>,
#  'cold': <gensim.models.keyedvectors.Vocab at 0x7fe97d780990>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x7fe97d780190>,
#  'ewr': <gensim.models.keyedvectors.Vocab at 0x7fe97d780890>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x7fe97d780310>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x7fe97d785150>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x7fe97d785090>,
#  'maneuver': <gensim.models.keyedvectors.Vocab at 0x7fe97d7856d0>,
#  'hi': <gensim.models.keyedvectors.Vocab at 0x7fe97d7850d0>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7fe97d785190>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x7fe97d785250>,
#  'birthday': <gensim.models.keyedvectors.Vocab at 0x7fe97d785310>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x7fe97d7853d0>,
#  'elevate': <gensim.models.keyedvectors.Vocab at 0x7fe97d785450>,
#  'entered': <gensim.models.keyedvectors.Vocab at 0x7fe97d785490>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7fe97d785510>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x7fe97d785550>,
#  'booking': <gensim.models.keyedvectors.Vocab at 0x7fe97d7855d0>,
#  'problems': <gensim.models.keyedvectors.Vocab at 0x7fe97d785610>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7fe97d7854d0>,
#  'operation': <gensim.models.keyedvectors.Vocab at 0x7fe97d785690>,
#  'club': <gensim.models.keyedvectors.Vocab at 0x7fe97d785590>,
#  'posted': <gensim.models.keyedvectors.Vocab at 0x7fe97d785350>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x7fe97d785650>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x7fe97d7851d0>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7fe97d785410>,
#  'expensive': <gensim.models.keyedvectors.Vocab at 0x7fe97d785110>,
#  'headphones': <gensim.models.keyedvectors.Vocab at 0x7fe97d785290>,
#  'iad': <gensim.models.keyedvectors.Vocab at 0x7fe97d785210>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7fe97d785050>,
#  'answering': <gensim.models.keyedvectors.Vocab at 0x7fe97d785e10>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7fe97d785750>,
#  'awaiting': <gensim.models.keyedvectors.Vocab at 0x7fe97d7857d0>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x7fe97d785810>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x7fe97d785890>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7fe97d7858d0>,
#  'prefer': <gensim.models.keyedvectors.Vocab at 0x7fe97d785950>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7fe97d785990>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x7fe97d785a10>,
#  'service': <gensim.models.keyedvectors.Vocab at 0x7fe97d785a50>,
#  'option': <gensim.models.keyedvectors.Vocab at 0x7fe97d785ad0>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x7fe97d785b10>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7fe97d785b90>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x7fe97d785bd0>,
#  'flights': <gensim.models.keyedvectors.Vocab at 0x7fe97d785c50>,
#  'hawaii': <gensim.models.keyedvectors.Vocab at 0x7fe97d785c90>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7fe97d785d10>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7fe97d785d50>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7fe97d785c10>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x7fe97d785dd0>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7fe97d785cd0>,
#  'rt': <gensim.models.keyedvectors.Vocab at 0x7fe97d785a90>,
#  'vibe': <gensim.models.keyedvectors.Vocab at 0x7fe97d785d90>,
#  'takeoff': <gensim.models.keyedvectors.Vocab at 0x7fe97d785910>,
#  'touchdown': <gensim.models.keyedvectors.Vocab at 0x7fe97d785b50>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7fe97d785790>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7fe97d7859d0>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7fe97d7852d0>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7fe97d785850>,
#  'airline': <gensim.models.keyedvectors.Vocab at 0x7fe97d785e50>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7fe97d785710>,
#  'hands': <gensim.models.keyedvectors.Vocab at 0x7fe97d785ed0>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7fe97d785390>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7fe97d785f50>,
#  'chat': <gensim.models.keyedvectors.Vocab at 0x7fe97d785e90>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7fe97d785fd0>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7fe97d785f10>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x7fe97d785f90>,
#  'view': <gensim.models.keyedvectors.Vocab at 0x7fe97d788150>,
#  'downtown': <gensim.models.keyedvectors.Vocab at 0x7fe97d788090>,
#  'los': <gensim.models.keyedvectors.Vocab at 0x7fe97d788790>,
#  'angeles': <gensim.models.keyedvectors.Vocab at 0x7fe97d7880d0>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x7fe97d788190>,
#  'beyond': <gensim.models.keyedvectors.Vocab at 0x7fe97d788250>,
#  'rain': <gensim.models.keyedvectors.Vocab at 0x7fe97d788310>,
#  'mountains': <gensim.models.keyedvectors.Vocab at 0x7fe97d788390>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x7fe97d7883d0>,
#  'flyer': <gensim.models.keyedvectors.Vocab at 0x7fe97d788450>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x7fe97d788490>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7fe97d788510>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7fe97d788550>,
#  'account': <gensim.models.keyedvectors.Vocab at 0x7fe97d7885d0>,
#  'plz': <gensim.models.keyedvectors.Vocab at 0x7fe97d788610>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x7fe97d788690>,
#  'upgrade': <gensim.models.keyedvectors.Vocab at 0x7fe97d7886d0>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x7fe97d788590>,
#  'unused': <gensim.models.keyedvectors.Vocab at 0x7fe97d788750>,
#  'ticket': <gensim.models.keyedvectors.Vocab at 0x7fe97d788650>,
#  'moved': <gensim.models.keyedvectors.Vocab at 0x7fe97d788410>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7fe97d788710>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x7fe97d788290>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7fe97d7884d0>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7fe97d788110>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7fe97d788350>,
#  'expires': <gensim.models.keyedvectors.Vocab at 0x7fe97d788210>,
#  'leaving': <gensim.models.keyedvectors.Vocab at 0x7fe97d7881d0>,
#  'dallas': <gensim.models.keyedvectors.Vocab at 0x7fe97d7887d0>,
#  'seattle': <gensim.models.keyedvectors.Vocab at 0x7fe97d7882d0>,
#  'feb': <gensim.models.keyedvectors.Vocab at 0x7fe97d788850>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7fe97d788050>,
#  'rock': <gensim.models.keyedvectors.Vocab at 0x7fe97d7888d0>,
#  'dream': <gensim.models.keyedvectors.Vocab at 0x7fe97d788810>,
#  'wow': <gensim.models.keyedvectors.Vocab at 0x7fe97d788950>,
#  'blew': <gensim.models.keyedvectors.Vocab at 0x7fe97d788990>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x7fe97d788ed0>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7fe97d788a10>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7fe97d788a90>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7fe97d788ad0>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x7fe97d788b50>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7fe97d788b90>,
#  'entertaining': <gensim.models.keyedvectors.Vocab at 0x7fe97d788c10>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x7fe97d788c50>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x7fe97d788cd0>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x7fe97d788d10>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7fe97d788d90>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x7fe97d788dd0>,
#  'shows': <gensim.models.keyedvectors.Vocab at 0x7fe97d788e50>,
#  'julie': <gensim.models.keyedvectors.Vocab at 0x7fe97d788e90>,
#  'andrews': <gensim.models.keyedvectors.Vocab at 0x7fe97d788f10>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7fe97d788f50>,
#  'impressive': <gensim.models.keyedvectors.Vocab at 0x7fe97d788fd0>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x7fe97d788e10>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7fe97d788bd0>,
#  'atlanta': <gensim.models.keyedvectors.Vocab at 0x7fe97d788d50>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x7fe97d788a50>,
#  'february': <gensim.models.keyedvectors.Vocab at 0x7fe97d788c90>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x7fe97d788910>,
#  'lga': <gensim.models.keyedvectors.Vocab at 0x7fe97d788b10>,
#  'dal': <gensim.models.keyedvectors.Vocab at 0x7fe97d788f90>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x7fe97d7889d0>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7fe97d788890>,
#  'page': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b050>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b090>,
#  'loads': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b0d0>,
#  'thx': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b110>,
#  'stat': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b150>,
#  'lady': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b190>,
#  'gaga': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b1d0>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b210>,
#  'carrie': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b250>,
#  'marketing': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b290>,
#  'song': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b2d0>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b310>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b350>,
#  'meh': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b390>,
#  'adding': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b3d0>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b410>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b450>,
#  'mary': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b490>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b4d0>,
#  'beat': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b510>,
#  'dca': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b550>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b590>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b5d0>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b610>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b650>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b690>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b6d0>,
#  'earlier': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b710>,
#  'tonight': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b750>,
#  'congrats': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b790>,
#  'winning': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b7d0>,
#  'award': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b810>,
#  'deals': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b850>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b890>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b8d0>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b910>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b950>,
#  'bag': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b990>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7fe97d70b9d0>,
#  'reservation': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ba10>,
#  'credit': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ba50>,
#  'card': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ba90>,
#  'modify': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bad0>,
#  'waive': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bb10>,
#  'fee': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bb50>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bb90>,
#  'customer': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bbd0>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bc10>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bc50>,
#  'tracking': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bc90>,
#  'booked': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bcd0>,
#  'baggage': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bd10>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bd50>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bd90>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bdd0>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7fe97d70be10>,
#  'dirty': <gensim.models.keyedvectors.Vocab at 0x7fe97d70be50>,
#  'tables': <gensim.models.keyedvectors.Vocab at 0x7fe97d70be90>,
#  'floors': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bed0>,
#  'worried': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bf10>,
#  'ride': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bf50>,
#  'plane': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bf90>,
#  'crew': <gensim.models.keyedvectors.Vocab at 0x7fe97d70bfd0>,
#  'airlines': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e050>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e090>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e0d0>,
#  'yall': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e110>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e150>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e190>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e1d0>,
#  'bill': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e210>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e250>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e290>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e2d0>,
#  'films': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e310>,
#  'feet': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e350>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e390>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e3d0>,
#  'policy': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e410>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e450>,
#  'bags': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e490>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e4d0>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e510>,
#  'speak': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e550>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e590>,
#  'asap': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e5d0>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e610>,
#  'biz': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e650>,
#  'traveler': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e690>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e6d0>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e710>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e750>,
#  'im': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e790>,
#  'interested': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e7d0>,
#  'whenever': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e810>,
#  'delayed': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e850>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e890>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e8d0>,
#  'cancelled': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e910>,
#  'four': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e950>,
#  'planned': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e990>,
#  'disappointing': <gensim.models.keyedvectors.Vocab at 0x7fe97d70e9d0>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ea10>,
#  'shared': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ea50>,
#  'business': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ea90>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ead0>,
#  'trouble': <gensim.models.keyedvectors.Vocab at 0x7fe97d70eb10>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x7fe97d70eb50>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7fe97d70eb90>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ebd0>,
#  'code': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ec10>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ec50>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ec90>,
#  'bet': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ecd0>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ed10>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ed50>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ed90>,
#  'happens': <gensim.models.keyedvectors.Vocab at 0x7fe97d70edd0>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ee10>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ee50>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ee90>,
#  'yeah': <gensim.models.keyedvectors.Vocab at 0x7fe97d70eed0>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ef10>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ef50>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x7fe97d70ef90>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x7fe97d70efd0>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x7fe97d712050>,
#  'disappointed': <gensim.models.keyedvectors.Vocab at 0x7fe97d712090>,
#  'flightled': <gensim.models.keyedvectors.Vocab at 0x7fe97d7120d0>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7fe97d712110>,
#  'jfk': <gensim.models.keyedvectors.Vocab at 0x7fe97d712150>,
#  'saturday': <gensim.models.keyedvectors.Vocab at 0x7fe97d712190>,
#  'landed': <gensim.models.keyedvectors.Vocab at 0x7fe97d7121d0>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x7fe97d712210>,
#  'friendly': <gensim.models.keyedvectors.Vocab at 0x7fe97d712250>,
#  'redirected': <gensim.models.keyedvectors.Vocab at 0x7fe97d712290>,
#  'btw': <gensim.models.keyedvectors.Vocab at 0x7fe97d7122d0>,
#  'isn': <gensim.models.keyedvectors.Vocab at 0x7fe97d712310>,
#  'user': <gensim.models.keyedvectors.Vocab at 0x7fe97d712350>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7fe97d712390>,
#  'desktop': <gensim.models.keyedvectors.Vocab at 0x7fe97d7123d0>,
#  'mobile': <gensim.models.keyedvectors.Vocab at 0x7fe97d712410>,
#  'scanned': <gensim.models.keyedvectors.Vocab at 0x7fe97d712450>,
#  'passengers': <gensim.models.keyedvectors.Vocab at 0x7fe97d712490>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x7fe97d7124d0>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x7fe97d712510>,
#  'remove': <gensim.models.keyedvectors.Vocab at 0x7fe97d712550>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7fe97d712590>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x7fe97d7125d0>,
#  'bin': <gensim.models.keyedvectors.Vocab at 0x7fe97d712610>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7fe97d712650>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7fe97d712690>,
#  'anyone': <gensim.models.keyedvectors.Vocab at 0x7fe97d7126d0>,
#  'doing': <gensim.models.keyedvectors.Vocab at 0x7fe97d712710>,
#  'useless': <gensim.models.keyedvectors.Vocab at 0x7fe97d712750>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x7fe97d712790>,
#  'prince': <gensim.models.keyedvectors.Vocab at 0x7fe97d7127d0>,
#  'sf': <gensim.models.keyedvectors.Vocab at 0x7fe97d712810>,
#  'thursday': <gensim.models.keyedvectors.Vocab at 0x7fe97d712850>,
#  'appointments': <gensim.models.keyedvectors.Vocab at 0x7fe97d712890>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x7fe97d7128d0>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x7fe97d712910>,
#  'unexpected': <gensim.models.keyedvectors.Vocab at 0x7fe97d712950>,
#  'layover': <gensim.models.keyedvectors.Vocab at 0x7fe97d712990>,
#  'vegas': <gensim.models.keyedvectors.Vocab at 0x7fe97d7129d0>,
#  'fuel': <gensim.models.keyedvectors.Vocab at 0x7fe97d712a10>,
#  'peeps': <gensim.models.keyedvectors.Vocab at 0x7fe97d712a50>,
#  'bought': <gensim.models.keyedvectors.Vocab at 0x7fe97d712a90>,
#  'apt': <gensim.models.keyedvectors.Vocab at 0x7fe97d712ad0>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7fe97d712b10>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7fe97d712b50>,
#  'exp': <gensim.models.keyedvectors.Vocab at 0x7fe97d712b90>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7fe97d712bd0>,
#  'hung': <gensim.models.keyedvectors.Vocab at 0x7fe97d712c10>,
#  'tripping': <gensim.models.keyedvectors.Vocab at 0x7fe97d712c50>,
#  'plain': <gensim.models.keyedvectors.Vocab at 0x7fe97d712c90>,
#  'text': <gensim.models.keyedvectors.Vocab at 0x7fe97d712cd0>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x7fe97d712d10>,
#  'enter': <gensim.models.keyedvectors.Vocab at 0x7fe97d712d50>,
#  'info': <gensim.models.keyedvectors.Vocab at 0x7fe97d712d90>,
#  'scheduled': <gensim.models.keyedvectors.Vocab at 0x7fe97d712dd0>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x7fe97d712e10>,
#  'weather': <gensim.models.keyedvectors.Vocab at 0x7fe97d712e50>,
#  'looks': <gensim.models.keyedvectors.Vocab at 0x7fe97d712e90>,
#  'getaway': <gensim.models.keyedvectors.Vocab at 0x7fe97d712ed0>,
#  'lots': <gensim.models.keyedvectors.Vocab at 0x7fe97d712f10>,
#  'cities': <gensim.models.keyedvectors.Vocab at 0x7fe97d712f50>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7fe97d712f90>,
#  'horrible': <gensim.models.keyedvectors.Vocab at 0x7fe97d712fd0>,
#  'concerned': <gensim.models.keyedvectors.Vocab at 0x7fe97d715050>,
#  'tech': <gensim.models.keyedvectors.Vocab at 0x7fe97d715090>,
#  'flown': <gensim.models.keyedvectors.Vocab at 0x7fe97d7150d0>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7fe97d715110>,
#  'helpful': <gensim.models.keyedvectors.Vocab at 0x7fe97d715150>,
#  'representatives': <gensim.models.keyedvectors.Vocab at 0x7fe97d715190>,
#  'comfortable': <gensim.models.keyedvectors.Vocab at 0x7fe97d7151d0>,
#  'rep': <gensim.models.keyedvectors.Vocab at 0x7fe97d715210>,
#  'kicked': <gensim.models.keyedvectors.Vocab at 0x7fe97d715250>,
#  'butt': <gensim.models.keyedvectors.Vocab at 0x7fe97d715290>,
#  'represents': <gensim.models.keyedvectors.Vocab at 0x7fe97d7152d0>,
#  'beautifully': <gensim.models.keyedvectors.Vocab at 0x7fe97d715310>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x7fe97d715350>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x7fe97d715390>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x7fe97d7153d0>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7fe97d715410>,
#  'secure': <gensim.models.keyedvectors.Vocab at 0x7fe97d715450>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x7fe97d715490>,
#  'gate': <gensim.models.keyedvectors.Vocab at 0x7fe97d7154d0>,
#  'waited': <gensim.models.keyedvectors.Vocab at 0x7fe97d715510>,
#  'kept': <gensim.models.keyedvectors.Vocab at 0x7fe97d715550>,
#  'browser': <gensim.models.keyedvectors.Vocab at 0x7fe97d715590>,
#  'reputation': <gensim.models.keyedvectors.Vocab at 0x7fe97d7155d0>,
#  'doesn': <gensim.models.keyedvectors.Vocab at 0x7fe97d715610>,
#  'compatible': <gensim.models.keyedvectors.Vocab at 0x7fe97d715650>,
#  'totally': <gensim.models.keyedvectors.Vocab at 0x7fe97d715690>,
#  'folks': <gensim.models.keyedvectors.Vocab at 0x7fe97d7156d0>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x7fe97d715710>,
#  'min': <gensim.models.keyedvectors.Vocab at 0x7fe97d715750>,
#  'delay': <gensim.models.keyedvectors.Vocab at 0x7fe97d715790>,
#  'connecting': <gensim.models.keyedvectors.Vocab at 0x7fe97d7157d0>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x7fe97d715810>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7fe97d715850>,
#  'outstanding': <gensim.models.keyedvectors.Vocab at 0x7fe97d715890>,
#  'san': <gensim.models.keyedvectors.Vocab at 0x7fe97d7158d0>,
#  'francisco': <gensim.models.keyedvectors.Vocab at 0x7fe97d715910>,
#  'absolute': <gensim.models.keyedvectors.Vocab at 0x7fe97d715950>,
#  'delighted': <gensim.models.keyedvectors.Vocab at 0x7fe97d715990>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x7fe97d7159d0>,
#  'complimentary': <gensim.models.keyedvectors.Vocab at 0x7fe97d715a10>,
#  'upgrades': <gensim.models.keyedvectors.Vocab at 0x7fe97d715a50>,
#  'thats': <gensim.models.keyedvectors.Vocab at 0x7fe97d715a90>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x7fe97d715ad0>,
#  'calling': <gensim.models.keyedvectors.Vocab at 0x7fe97d715b10>,
#  'intern': <gensim.models.keyedvectors.Vocab at 0x7fe97d715b50>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x7fe97d715b90>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x7fe97d715bd0>,
#  'nonstop': <gensim.models.keyedvectors.Vocab at 0x7fe97d715c10>,
#  'depart': <gensim.models.keyedvectors.Vocab at 0x7fe97d715c50>,
#  'failing': <gensim.models.keyedvectors.Vocab at 0x7fe97d715c90>,
#  'customers': <gensim.models.keyedvectors.Vocab at 0x7fe97d715cd0>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7fe97d715d10>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x7fe97d715d50>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x7fe97d715d90>,
#  'link': <gensim.models.keyedvectors.Vocab at 0x7fe97d715dd0>,
#  'tsa': <gensim.models.keyedvectors.Vocab at 0x7fe97d715e10>,
#  'pre': <gensim.models.keyedvectors.Vocab at 0x7fe97d715e50>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x7fe97d715e90>,
#  'hotel': <gensim.models.keyedvectors.Vocab at 0x7fe97d715ed0>,
#  'hotline': <gensim.models.keyedvectors.Vocab at 0x7fe97d715f10>,
#  'cabo': <gensim.models.keyedvectors.Vocab at 0x7fe97d715f50>,
#  'assistance': <gensim.models.keyedvectors.Vocab at 0x7fe97d715f90>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7fe97d715fd0>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a050>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a090>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a0d0>,
#  'register': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a110>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a150>,
#  'dulles': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a190>,
#  'queue': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a1d0>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a210>,
#  'pls': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a250>,
#  'advise': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a290>,
#  'dropped': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a2d0>,
#  'track': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a310>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a350>,
#  'xoxo': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a390>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a3d0>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a410>,
#  'creates': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a450>,
#  'anxiety': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a490>,
#  'paying': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a4d0>,
#  'extra': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a510>,
#  'bucks': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a550>,
#  'luggage': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a590>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a5d0>,
#  'afford': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a610>,
#  'hiring': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a650>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a690>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a6d0>,
#  'takes': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a710>,
#  'cake': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a750>,
#  'flt': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a790>,
#  'sooner': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a7d0>,
#  'midnight': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a810>,
#  'monday': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a850>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a890>,
#  'imagine': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a8d0>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a910>,
#  'web': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a950>,
#  'indicates': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a990>,
#  'dude': <gensim.models.keyedvectors.Vocab at 0x7fe97d71a9d0>,
#  'staff': <gensim.models.keyedvectors.Vocab at 0x7fe97d71aa10>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x7fe97d71aa50>,
#  'ran': <gensim.models.keyedvectors.Vocab at 0x7fe97d71aa90>,
#  'spoiled': <gensim.models.keyedvectors.Vocab at 0x7fe97d71aad0>,
#  'comfort': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ab10>,
#  'paid': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ab50>,
#  'premium': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ab90>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x7fe97d71abd0>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ac10>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ac50>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ac90>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x7fe97d71acd0>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ad10>,
#  'infant': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ad50>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ad90>,
#  'giving': <gensim.models.keyedvectors.Vocab at 0x7fe97d71add0>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ae10>,
#  'welcome': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ae50>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ae90>,
#  'dm': <gensim.models.keyedvectors.Vocab at 0x7fe97d71aed0>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x7fe97d71af10>,
#  'damaged': <gensim.models.keyedvectors.Vocab at 0x7fe97d71af50>,
#  'destroyed': <gensim.models.keyedvectors.Vocab at 0x7fe97d71af90>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7fe97d71afd0>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c050>,
#  'kids': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c090>,
#  'priority': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c0d0>,
#  'boarding': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c110>,
#  'checking': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c150>,
#  'tickets': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c190>,
#  'purchased': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c1d0>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c210>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c250>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c290>,
#  'definitely': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c2d0>,
#  'dfw': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c310>,
#  'license': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c350>,
#  'expired': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c390>,
#  'friday': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c3d0>,
#  'keeps': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c410>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c450>,
#  'contact': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c490>,
#  'minute': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c4d0>,
#  'reschedule': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c510>,
#  'button': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c550>,
#  'fix': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c590>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c5d0>,
#  'checked': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c610>,
#  'email': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c650>,
#  'tomorrow': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c690>,
#  'unacceptable': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c6d0>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c710>,
#  'flighted': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c750>,
#  'stuck': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c790>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c7d0>,
#  'wine': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c810>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c850>,
#  'offered': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c890>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c8d0>,
#  'browsers': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c910>,
#  'css': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c950>,
#  'agent': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c990>,
#  'silver': <gensim.models.keyedvectors.Vocab at 0x7fe97d71c9d0>,
#  'closed': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ca10>,
#  'assist': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ca50>,
#  'plans': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ca90>,
#  'austin': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cad0>,
#  'route': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cb10>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cb50>,
#  'receive': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cb90>,
#  'reply': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cbd0>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cc10>,
#  'logan': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cc50>,
#  'airport': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cc90>,
#  'waiting': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ccd0>,
#  'checkin': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cd10>,
#  'desk': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cd50>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cd90>,
#  'jump': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cdd0>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ce10>,
#  'beats': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ce50>,
#  'views': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ce90>,
#  'luv': <gensim.models.keyedvectors.Vocab at 0x7fe97d71ced0>,
#  'investor': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cf10>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cf50>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cf90>,
#  'begin': <gensim.models.keyedvectors.Vocab at 0x7fe97d71cfd0>,
#  'april': <gensim.models.keyedvectors.Vocab at 0x7fe97d720050>,
#  'fuck': <gensim.models.keyedvectors.Vocab at 0x7fe97d720090>,
#  'fl': <gensim.models.keyedvectors.Vocab at 0x7fe97d7200d0>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x7fe97d720110>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7fe97d720150>,
#  'apologies': <gensim.models.keyedvectors.Vocab at 0x7fe97d720190>,
#  'worse': <gensim.models.keyedvectors.Vocab at 0x7fe97d7201d0>,
#  'respond': <gensim.models.keyedvectors.Vocab at 0x7fe97d720210>,
#  'spend': <gensim.models.keyedvectors.Vocab at 0x7fe97d720250>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7fe97d720290>,
#  'stranded': <gensim.models.keyedvectors.Vocab at 0x7fe97d7202d0>,
#  'landing': <gensim.models.keyedvectors.Vocab at 0x7fe97d720310>,
#  'reimburse': <gensim.models.keyedvectors.Vocab at 0x7fe97d720350>,
# ...
#  'met': <gensim.models.keyedvectors.Vocab at 0x7fe97d7205d0>,
#  'restr': <gensim.models.keyedvectors.Vocab at 0x7fe97d720610>,
#  'cmh': <gensim.models.keyedvectors.Vocab at 0x7fe97d720650>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7fe97d720690>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7fe97d7206d0>,
#  'thrown': <gensim.models.keyedvectors.Vocab at 0x7fe97d720710>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7fe97d720750>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x7fe97d720790>,
#  'stuff': <gensim.models.keyedvectors.Vocab at 0x7fe97d7207d0>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x7fe97d720810>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x7fe97d720850>,
#  'finding': <gensim.models.keyedvectors.Vocab at 0x7fe97d720890>,
#  'missing': <gensim.models.keyedvectors.Vocab at 0x7fe97d7208d0>,
#  'item': <gensim.models.keyedvectors.Vocab at 0x7fe97d720910>,
#  'headed': <gensim.models.keyedvectors.Vocab at 0x7fe97d720950>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x7fe97d720990>,
#  'suck': <gensim.models.keyedvectors.Vocab at 0x7fe97d7209d0>,
#  'rec': <gensim.models.keyedvectors.Vocab at 0x7fe97d720a10>,
#  'flightlation': <gensim.models.keyedvectors.Vocab at 0x7fe97d720a50>,
#  'notice': <gensim.models.keyedvectors.Vocab at 0x7fe97d720a90>,
#  'ps': <gensim.models.keyedvectors.Vocab at 0x7fe97d720ad0>,
#  'driving': <gensim.models.keyedvectors.Vocab at 0x7fe97d720b10>,
#  'mon': <gensim.models.keyedvectors.Vocab at 0x7fe97d720b50>,
#  'boston': <gensim.models.keyedvectors.Vocab at 0x7fe97d720b90>,
#  'psp': <gensim.models.keyedvectors.Vocab at 0x7fe97d720bd0>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x7fe97d720c10>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x7fe97d720c50>,
#  'dancing': <gensim.models.keyedvectors.Vocab at 0x7fe97d720c90>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7fe97d720cd0>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7fe97d720d10>,
#  'dance': <gensim.models.keyedvectors.Vocab at 0x7fe97d720d50>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x7fe97d720d90>,
#  'apparently': <gensim.models.keyedvectors.Vocab at 0x7fe97d720dd0>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x7fe97d720e10>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x7fe97d720e50>,
#  'nervous': <gensim.models.keyedvectors.Vocab at 0x7fe97d720e90>,
#  'dc': <gensim.models.keyedvectors.Vocab at 0x7fe97d720ed0>,
#  'sent': <gensim.models.keyedvectors.Vocab at 0x7fe97d720f10>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x7fe97d720f50>,
#  'virginamerica': <gensim.models.keyedvectors.Vocab at 0x7fe97d720f90>,
#  'wing': <gensim.models.keyedvectors.Vocab at 0x7fe97d720fd0>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7fe97d723050>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7fe97d723090>,
#  'goodness': <gensim.models.keyedvectors.Vocab at 0x7fe97d7230d0>,
#  'pressure': <gensim.models.keyedvectors.Vocab at 0x7fe97d723110>,
#  'texas': <gensim.models.keyedvectors.Vocab at 0x7fe97d723150>,
#  'crisis': <gensim.models.keyedvectors.Vocab at 0x7fe97d723190>,
#  'ny': <gensim.models.keyedvectors.Vocab at 0x7fe97d7231d0>,
#  'pilots': <gensim.models.keyedvectors.Vocab at 0x7fe97d723210>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x7fe97d723250>,
#  'snow': <gensim.models.keyedvectors.Vocab at 0x7fe97d723290>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x7fe97d7232d0>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7fe97d723310>,
#  'afternoon': <gensim.models.keyedvectors.Vocab at 0x7fe97d723350>,
#  'row': <gensim.models.keyedvectors.Vocab at 0x7fe97d723390>,
#  'recline': <gensim.models.keyedvectors.Vocab at 0x7fe97d7233d0>,
#  'mention': <gensim.models.keyedvectors.Vocab at 0x7fe97d723410>,
#  'mechanical': <gensim.models.keyedvectors.Vocab at 0x7fe97d723450>,
#  'handle': <gensim.models.keyedvectors.Vocab at 0x7fe97d723490>,
#  'pros': <gensim.models.keyedvectors.Vocab at 0x7fe97d7234d0>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x7fe97d723510>,
#  'precipitation': <gensim.models.keyedvectors.Vocab at 0x7fe97d723550>,
#  'scared': <gensim.models.keyedvectors.Vocab at 0x7fe97d723590>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x7fe97d7235d0>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x7fe97d723610>,
#  'rescheduling': <gensim.models.keyedvectors.Vocab at 0x7fe97d723650>,
#  'charged': <gensim.models.keyedvectors.Vocab at 0x7fe97d723690>,
#  'refusing': <gensim.models.keyedvectors.Vocab at 0x7fe97d7236d0>,
#  'refund': <gensim.models.keyedvectors.Vocab at 0x7fe97d723710>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x7fe97d723750>,
#  'safari': <gensim.models.keyedvectors.Vocab at 0x7fe97d723790>,
#  'iphone': <gensim.models.keyedvectors.Vocab at 0x7fe97d7237d0>,
#  'mac': <gensim.models.keyedvectors.Vocab at 0x7fe97d723810>,
#  'ipad': <gensim.models.keyedvectors.Vocab at 0x7fe97d723850>,
#  'passbook': <gensim.models.keyedvectors.Vocab at 0x7fe97d723890>,
#  'clicking': <gensim.models.keyedvectors.Vocab at 0x7fe97d7238d0>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x7fe97d723910>,
#  'broken': <gensim.models.keyedvectors.Vocab at 0x7fe97d723950>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x7fe97d723990>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x7fe97d7239d0>,
#  'rescheduled': <gensim.models.keyedvectors.Vocab at 0x7fe97d723a10>,
#  'sec': <gensim.models.keyedvectors.Vocab at 0x7fe97d723a50>,
#  'gonna': <gensim.models.keyedvectors.Vocab at 0x7fe97d723a90>,
#  'land': <gensim.models.keyedvectors.Vocab at 0x7fe97d723ad0>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x7fe97d723b10>,
#  'ugh': <gensim.models.keyedvectors.Vocab at 0x7fe97d723b50>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x7fe97d723b90>,
#  'subsequent': <gensim.models.keyedvectors.Vocab at 0x7fe97d723bd0>,
#  'putting': <gensim.models.keyedvectors.Vocab at 0x7fe97d723c10>,
#  'bug': <gensim.models.keyedvectors.Vocab at 0x7fe97d723c50>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7fe97d723c90>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x7fe97d723cd0>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x7fe97d723d10>,
#  'attendant': <gensim.models.keyedvectors.Vocab at 0x7fe97d723d50>,
#  'reset': <gensim.models.keyedvectors.Vocab at 0x7fe97d723d90>,
#  'password': <gensim.models.keyedvectors.Vocab at 0x7fe97d723dd0>,
#  'arrives': <gensim.models.keyedvectors.Vocab at 0x7fe97d723e10>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7fe97d723e50>,
#  'silicon': <gensim.models.keyedvectors.Vocab at 0x7fe97d723e90>,
#  'nicely': <gensim.models.keyedvectors.Vocab at 0x7fe97d723ed0>,
#  'watching': <gensim.models.keyedvectors.Vocab at 0x7fe97d723f10>,
#  'oscars': <gensim.models.keyedvectors.Vocab at 0x7fe97d723f50>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7fe97d723f90>,
#  'departure': <gensim.models.keyedvectors.Vocab at 0x7fe97d723fd0>,
#  'todays': <gensim.models.keyedvectors.Vocab at 0x7fe97d728050>,
#  'palm': <gensim.models.keyedvectors.Vocab at 0x7fe97d728090>,
#  'springs': <gensim.models.keyedvectors.Vocab at 0x7fe97d7280d0>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x7fe97d728110>,
#  'hahaha': <gensim.models.keyedvectors.Vocab at 0x7fe97d728150>,
#  'sounds': <gensim.models.keyedvectors.Vocab at 0x7fe97d728190>,
#  'fun': <gensim.models.keyedvectors.Vocab at 0x7fe97d7281d0>,
#  'updates': <gensim.models.keyedvectors.Vocab at 0x7fe97d728210>,
#  'unusable': <gensim.models.keyedvectors.Vocab at 0x7fe97d728250>,
#  'count': <gensim.models.keyedvectors.Vocab at 0x7fe97d728290>,
#  'somehow': <gensim.models.keyedvectors.Vocab at 0x7fe97d7282d0>,
#  'continues': <gensim.models.keyedvectors.Vocab at 0x7fe97d728310>,
#  'helping': <gensim.models.keyedvectors.Vocab at 0x7fe97d728350>,
#  'sorted': <gensim.models.keyedvectors.Vocab at 0x7fe97d728390>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x7fe97d7283d0>,
#  'blasting': <gensim.models.keyedvectors.Vocab at 0x7fe97d728410>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7fe97d728450>,
#  'iced': <gensim.models.keyedvectors.Vocab at 0x7fe97d728490>,
#  'coffee': <gensim.models.keyedvectors.Vocab at 0x7fe97d7284d0>,
#  'passenger': <gensim.models.keyedvectors.Vocab at 0x7fe97d728510>,
#  'assaulted': <gensim.models.keyedvectors.Vocab at 0x7fe97d728550>,
#  'shouldn': <gensim.models.keyedvectors.Vocab at 0x7fe97d728590>,
#  'trust': <gensim.models.keyedvectors.Vocab at 0x7fe97d7285d0>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7fe97d728610>,
#  'filed': <gensim.models.keyedvectors.Vocab at 0x7fe97d728650>,
#  'destination': <gensim.models.keyedvectors.Vocab at 0x7fe97d728690>,
#  'severely': <gensim.models.keyedvectors.Vocab at 0x7fe97d7286d0>,
#  'wheel': <gensim.models.keyedvectors.Vocab at 0x7fe97d728710>,
#  'wasn': <gensim.models.keyedvectors.Vocab at 0x7fe97d728750>,
#  'itinerary': <gensim.models.keyedvectors.Vocab at 0x7fe97d728790>,
#  'shift': <gensim.models.keyedvectors.Vocab at 0x7fe97d7287d0>,
#  'impending': <gensim.models.keyedvectors.Vocab at 0x7fe97d728810>,
#  'painless': <gensim.models.keyedvectors.Vocab at 0x7fe97d728850>,
#  'girls': <gensim.models.keyedvectors.Vocab at 0x7fe97d728890>,
#  'inspired': <gensim.models.keyedvectors.Vocab at 0x7fe97d7288d0>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x7fe97d728910>,
#  'woaw': <gensim.models.keyedvectors.Vocab at 0x7fe97d728950>,
#  'event': <gensim.models.keyedvectors.Vocab at 0x7fe97d728990>,
#  'march': <gensim.models.keyedvectors.Vocab at 0x7fe97d7289d0>,
#  'abq': <gensim.models.keyedvectors.Vocab at 0x7fe97d728a10>,
#  'entire': <gensim.models.keyedvectors.Vocab at 0x7fe97d728a50>,
#  'expectations': <gensim.models.keyedvectors.Vocab at 0x7fe97d728a90>,
#  'shares': <gensim.models.keyedvectors.Vocab at 0x7fe97d728ad0>,
#  'santa': <gensim.models.keyedvectors.Vocab at 0x7fe97d728b10>,
#  'sentinel': <gensim.models.keyedvectors.Vocab at 0x7fe97d728b50>,
#  'luxuries': <gensim.models.keyedvectors.Vocab at 0x7fe97d728b90>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x7fe97d728bd0>,
#  'requested': <gensim.models.keyedvectors.Vocab at 0x7fe97d728c10>,
#  'window': <gensim.models.keyedvectors.Vocab at 0x7fe97d728c50>,
#  'confirmed': <gensim.models.keyedvectors.Vocab at 0x7fe97d728c90>,
#  'treat': <gensim.models.keyedvectors.Vocab at 0x7fe97d728cd0>,
#  'grand': <gensim.models.keyedvectors.Vocab at 0x7fe97d728d10>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x7fe97d728d50>,
#  'exhausted': <gensim.models.keyedvectors.Vocab at 0x7fe97d728d90>,
#  'frequent': <gensim.models.keyedvectors.Vocab at 0x7fe97d728dd0>,
#  'flier': <gensim.models.keyedvectors.Vocab at 0x7fe97d728e10>,
#  'inconvenience': <gensim.models.keyedvectors.Vocab at 0x7fe97d728e50>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7fe97d728e90>,
#  'boo': <gensim.models.keyedvectors.Vocab at 0x7fe97d728ed0>,
#  'refunding': <gensim.models.keyedvectors.Vocab at 0x7fe97d728f10>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7fe97d728f50>,
#  'financial': <gensim.models.keyedvectors.Vocab at 0x7fe97d728f90>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x7fe97d728fd0>,
#  'usa': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a050>,
#  'adds': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a090>,
#  'pillows': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a0d0>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a110>,
#  'lie': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a150>,
#  'flat': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a190>,
#  'arms': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a1d0>,
#  'race': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a210>,
#  'advantage': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a250>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a290>,
#  'inflight': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a2d0>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a310>,
#  'salt': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a350>,
#  'cabin': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a390>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a3d0>,
#  'selected': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a410>,
#  'fav': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a450>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a490>,
#  'female': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a4d0>,
#  'pilot': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a510>,
#  'paris': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a550>,
#  'surgery': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a590>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a5d0>,
#  'doctor': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a610>,
#  'contacted': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a650>,
#  'charging': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a690>,
#  'suitcase': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a6d0>,
#  'errors': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a710>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a750>,
#  'ah': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a790>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a7d0>,
#  'regulation': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a810>,
#  'atlantic': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a850>,
#  'gold': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a890>,
#  'benefits': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a8d0>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a910>,
#  'ordered': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a950>,
#  'drinks': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a990>,
#  'screen': <gensim.models.keyedvectors.Vocab at 0x7fe97d72a9d0>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x7fe97d72aa10>,
#  'soooo': <gensim.models.keyedvectors.Vocab at 0x7fe97d72aa50>,
#  'seatbelt': <gensim.models.keyedvectors.Vocab at 0x7fe97d72aa90>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x7fe97d72aad0>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x7fe97d72ab10>,
#  'turbulence': <gensim.models.keyedvectors.Vocab at 0x7fe97d72ab50>,
#  'consecutive': <gensim.models.keyedvectors.Vocab at 0x7fe97d72ab90>,
#  'profit': <gensim.models.keyedvectors.Vocab at 0x7fe97d72abd0>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x7fe97d72ac10>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7fe97d72ac50>,
#  'dislike': <gensim.models.keyedvectors.Vocab at 0x7fe97d72ac90>,
#  'exceed': <gensim.models.keyedvectors.Vocab at 0x7fe97d72acd0>,
#  'forecasts': <gensim.models.keyedvectors.Vocab at 0x7fe97d72ad10>,
#  'position': <gensim.models.keyedvectors.Vocab at 0x7fe97d72ad50>,
#  'wondering': <gensim.models.keyedvectors.Vocab at 0x7fe97d72ad90>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x7fe97d72add0>,
#  'profitability': <gensim.models.keyedvectors.Vocab at 0x7fe97d72ae10>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x7fe97d72ae50>,
#  'revenue': <gensim.models.keyedvectors.Vocab at 0x7fe97d72ae90>,
#  'gives': <gensim.models.keyedvectors.Vocab at 0x7fe97d72aed0>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x7fe97d72af10>,
#  'sees': <gensim.models.keyedvectors.Vocab at 0x7fe97d72af50>,
#  'increased': <gensim.models.keyedvectors.Vocab at 0x7fe97d72af90>,
#  'competition': <gensim.models.keyedvectors.Vocab at 0x7fe97d72afd0>,
#  'ct': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e050>,
#  'sort': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e090>,
#  'sos': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e0d0>,
#  'delays': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e110>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e150>,
#  'emails': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e190>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e1d0>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e210>,
#  'winds': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e250>,
#  'temperature': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e290>,
#  'degrees': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e2d0>,
#  'loved': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e310>,
#  'mostly': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e350>,
#  'safety': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e390>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7fe97d72e3d0>,
#  ...}

# %%
model.wv['said']
# Out:
# array([-0.22195518,  0.1055297 ,  0.06508979, -0.01149802,  0.15914424,
#        -0.12435319, -0.27581578,  0.25340787,  0.0596672 , -0.07605531,
#         0.07415222,  0.13737915, -0.02540693,  0.14053811, -0.28038514,
#         0.12077425,  0.21222925,  0.3305596 , -0.16972028,  0.06715845,
#        -0.2084009 , -0.18451948, -0.0761303 , -0.12065084, -0.17458564,
#        -0.04296313,  0.33371177, -0.06007433,  0.06708748,  0.15179907,
#         0.14910921, -0.14636719,  0.01630866, -0.03713298, -0.04195356,
#         0.16229518, -0.05382098, -0.3371251 , -0.14090554, -0.20363897,
#        -0.09885361, -0.02462752, -0.03369132,  0.29601544,  0.07807993,
#         0.12111193,  0.22463797,  0.18080628,  0.15442052,  0.1421536 ,
#         0.07993342,  0.02137627, -0.18292482,  0.15152365, -0.03241241,
#        -0.02939419,  0.20796444, -0.17712289, -0.13211599, -0.27739027,
#        -0.20781703, -0.277593  , -0.08194861,  0.0511935 ,  0.1103516 ,
#        -0.07154955,  0.39921916, -0.21055584,  0.10540969,  0.1144269 ,
#        -0.21164897, -0.31664872,  0.17348978,  0.19360596,  0.07781198,
#         0.03672025,  0.15284386, -0.3575579 , -0.05628793,  0.120347  ,
#        -0.01032147,  0.10666065, -0.3897788 ,  0.13389586, -0.161327  ,
#        -0.40754434,  0.23296514,  0.4053574 , -0.02703148, -0.03862339,
#         0.05795093,  0.27187353, -0.3944937 ,  0.05573072,  0.2890366 ,
#         0.23621747, -0.23951687,  0.18053173,  0.08488464,  0.0121602 ,
#        -0.00932305, -0.22760844,  0.02964606,  0.01410812, -0.0605289 ,
#        -0.00307987,  0.0934595 , -0.00980898, -0.45612288, -0.2670162 ,
#        -0.09378899, -0.18256216, -0.04358229,  0.14749299,  0.10736659,
#         0.17120732, -0.04348841, -0.13673939,  0.16725771,  0.3717637 ,
#        -0.12288786,  0.05957182,  0.14896968,  0.13207264, -0.280531  ,
#         0.02262834,  0.08590095,  0.10760993,  0.26238525,  0.09037185,
#        -0.4463506 , -0.05013481, -0.00830725,  0.17869098, -0.31477672,
#        -0.12007878, -0.17507495,  0.217419  , -0.00930806,  0.07189242,
#        -0.34817266, -0.12002137, -0.02667059, -0.6658005 , -0.24440388,
#         0.5007366 , -0.17044647, -0.00574308,  0.00712446, -0.00721622],
#       dtype=float32)

# %%
model.wv['said']
# Out:
# array([-0.22195518,  0.1055297 ,  0.06508979, -0.01149802,  0.15914424,
#        -0.12435319, -0.27581578,  0.25340787,  0.0596672 , -0.07605531,
#         0.07415222,  0.13737915, -0.02540693,  0.14053811, -0.28038514,
#         0.12077425,  0.21222925,  0.3305596 , -0.16972028,  0.06715845,
#        -0.2084009 , -0.18451948, -0.0761303 , -0.12065084, -0.17458564,
#        -0.04296313,  0.33371177, -0.06007433,  0.06708748,  0.15179907,
#         0.14910921, -0.14636719,  0.01630866, -0.03713298, -0.04195356,
#         0.16229518, -0.05382098, -0.3371251 , -0.14090554, -0.20363897,
#        -0.09885361, -0.02462752, -0.03369132,  0.29601544,  0.07807993,
#         0.12111193,  0.22463797,  0.18080628,  0.15442052,  0.1421536 ,
#         0.07993342,  0.02137627, -0.18292482,  0.15152365, -0.03241241,
#        -0.02939419,  0.20796444, -0.17712289, -0.13211599, -0.27739027,
#        -0.20781703, -0.277593  , -0.08194861,  0.0511935 ,  0.1103516 ,
#        -0.07154955,  0.39921916, -0.21055584,  0.10540969,  0.1144269 ,
#        -0.21164897, -0.31664872,  0.17348978,  0.19360596,  0.07781198,
#         0.03672025,  0.15284386, -0.3575579 , -0.05628793,  0.120347  ,
#        -0.01032147,  0.10666065, -0.3897788 ,  0.13389586, -0.161327  ,
#        -0.40754434,  0.23296514,  0.4053574 , -0.02703148, -0.03862339,
#         0.05795093,  0.27187353, -0.3944937 ,  0.05573072,  0.2890366 ,
#         0.23621747, -0.23951687,  0.18053173,  0.08488464,  0.0121602 ,
#        -0.00932305, -0.22760844,  0.02964606,  0.01410812, -0.0605289 ,
#        -0.00307987,  0.0934595 , -0.00980898, -0.45612288, -0.2670162 ,
#        -0.09378899, -0.18256216, -0.04358229,  0.14749299,  0.10736659,
#         0.17120732, -0.04348841, -0.13673939,  0.16725771,  0.3717637 ,
#        -0.12288786,  0.05957182,  0.14896968,  0.13207264, -0.280531  ,
#         0.02262834,  0.08590095,  0.10760993,  0.26238525,  0.09037185,
#        -0.4463506 , -0.05013481, -0.00830725,  0.17869098, -0.31477672,
#        -0.12007878, -0.17507495,  0.217419  , -0.00930806,  0.07189242,
#        -0.34817266, -0.12002137, -0.02667059, -0.6658005 , -0.24440388,
#         0.5007366 , -0.17044647, -0.00574308,  0.00712446, -0.00721622],
#       dtype=float32)

# %% [markdown]
# ### Criando uma representação 2d dos dados com compressão de coordenadas.

# %%
dici = model.wv.vocab.keys()

dici = list(dici)

dici = dici[0:150]

dici

#dici = {pal : model.wv.vocab[pal] for pal in dici}
# Out:
# ['what',
#  'said',
#  'plus',
#  'you',
#  've',
#  'added',
#  'commercials',
#  'to',
#  'the',
#  'experience',
#  'didn',
#  'today',
#  'must',
#  'mean',
#  'need',
#  'take',
#  'another',
#  'trip',
#  'it',
#  'really',
#  'aggressive',
#  'blast',
#  'obnoxious',
#  'entertainment',
#  'in',
#  'your',
#  'guests',
#  'faces',
#  'amp',
#  'they',
#  'have',
#  'little',
#  'recourse',
#  'and',
#  'big',
#  'bad',
#  'thing',
#  'about',
#  'seriously',
#  'would',
#  'pay',
#  'flight',
#  'for',
#  'seats',
#  'that',
#  'this',
#  'playing',
#  'only',
#  'flying',
#  'va',
#  'yes',
#  'nearly',
#  'every',
#  'time',
#  'fly',
#  'vx',
#  'ear',
#  'won',
#  'go',
#  'away',
#  'missed',
#  'prime',
#  'opportunity',
#  'men',
#  'without',
#  'hats',
#  'there',
#  'well',
#  'but',
#  'now',
#  'do',
#  'was',
#  'amazing',
#  'arrived',
#  'an',
#  'hour',
#  'early',
#  're',
#  'too',
#  'good',
#  'me',
#  'did',
#  'know',
#  'suicide',
#  'is',
#  'second',
#  'leading',
#  'cause',
#  'of',
#  'death',
#  'among',
#  'teens',
#  'lt',
#  'pretty',
#  'so',
#  'much',
#  'better',
#  'than',
#  'such',
#  'great',
#  'deal',
#  'already',
#  'thinking',
#  'my',
#  'nd',
#  'haven',
#  'even',
#  'gone',
#  'on',
#  'st',
#  'yet',
#  'skies',
#  'again',
#  'all',
#  'from',
#  'travel',
#  'thanks',
#  'sfo',
#  'pdx',
#  'schedule',
#  'still',
#  'mia',
#  'excited',
#  'first',
#  'cross',
#  'country',
#  'lax',
#  'mco',
#  'heard',
#  'nothing',
#  'things',
#  'virgin',
#  'america',
#  'flew',
#  'nyc',
#  'last',
#  'week',
#  'couldn',
#  'fully',
#  'sit',
#  'seat',
#  'due',
#  'two',
#  'large',
#  'gentleman',
#  'either',
#  'side',
#  'help',
#  'be',
#  'amazingly']

# %%
X = model[dici]

X
# Out:
# /home/matheus/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([[-0.01753943, -0.18346931,  0.04267684, ..., -0.27133423,
#          0.02302297,  0.08370329],
#        [-0.22195518,  0.1055297 ,  0.06508979, ..., -0.00574308,
#          0.00712446, -0.00721622],
#        [-0.1057809 ,  0.2376083 , -0.006036  , ..., -0.03496452,
#          0.1173802 ,  0.00410145],
#        ...,
#        [ 0.29362547,  0.4900166 ,  0.08704971, ..., -0.23541215,
#          0.33574817, -0.25852385],
#        [ 0.2768672 ,  0.40480313,  0.21283989, ..., -0.0549668 ,
#          0.03566377,  0.11550132],
#        [ 0.00632307,  0.0890686 ,  0.00329806, ..., -0.02838707,
#          0.09495945, -0.0257849 ]], dtype=float32)

# %%
tsne_model = TSNE(perplexity=40,n_components=2,init="pca", n_iter=5000, random_state=23)

Y = tsne_model.fit_transform(X)

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.scatter(Y[:, 0], Y[:, 1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-77dcee743b6f> in <module>
# ----> 1 fig, ax = plt.subplots(figsize=(20,10))
#       2 ax.scatter(Y[:, 0], Y[:, 1])
#
# NameError: name 'plt' is not defined
